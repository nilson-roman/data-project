# %%
from bs4 import BeautifulSoup
import json
import pandas as pd
import requests
import ast
import time
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://www.ibge.gov.br/explica/codigos-dos-municipios.php'

# %%
soup = BeautifulSoup(requests.get(url).content)

# %%
for mun in soup.find_all('div',{'class' : 'container-codigos'}):
    print(mun.find('td',{'class': 'numero'}))
# Out:
# <td class="numero"><a href="#AC">12<span class="saiba-mais-tag">ver municípios</span></a></td>

# %%
boody_num = soup.find('div',{'class' : 'container-codigos'})

# %%
#  index 27 is when begin munip codes 
boody_num.find_all('td',{'class': 'numero'})[27:28]
# Out:
# [<td class="numero">1200013</td>,
#  <td class="numero">1200054</td>,
#  <td class="numero">1200104</td>,
#  <td class="numero">1200138</td>,
#  <td class="numero">1200179</td>,
#  <td class="numero">1200203</td>,
#  <td class="numero">1200252</td>,
#  <td class="numero">1200302</td>,
#  <td class="numero">1200328</td>,
#  <td class="numero">1200336</td>,
#  <td class="numero">1200344</td>,
#  <td class="numero">1200351</td>,
#  <td class="numero">1200385</td>,
#  <td class="numero">1200807</td>,
#  <td class="numero">1200393</td>,
#  <td class="numero">1200401</td>,
#  <td class="numero">1200427</td>,
#  <td class="numero">1200435</td>,
#  <td class="numero">1200500</td>,
#  <td class="numero">1200450</td>,
#  <td class="numero">1200609</td>,
#  <td class="numero">1200708</td>,
#  <td class="numero">2700102</td>,
#  <td class="numero">2700201</td>,
#  <td class="numero">2700300</td>,
#  <td class="numero">2700409</td>,
#  <td class="numero">2700508</td>,
#  <td class="numero">2700607</td>,
#  <td class="numero">2700706</td>,
#  <td class="numero">2700805</td>,
#  <td class="numero">2700904</td>,
#  <td class="numero">2701001</td>,
#  <td class="numero">2701100</td>,
#  <td class="numero">2701209</td>,
#  <td class="numero">2701308</td>,
#  <td class="numero">2701357</td>,
#  <td class="numero">2701407</td>,
#  <td class="numero">2701506</td>,
#  <td class="numero">2701605</td>,
#  <td class="numero">2701704</td>,
#  <td class="numero">2701803</td>,
#  <td class="numero">2701902</td>,
#  <td class="numero">2702009</td>,
#  <td class="numero">2702108</td>,
#  <td class="numero">2702207</td>,
#  <td class="numero">2702306</td>,
#  <td class="numero">2702355</td>,
#  <td class="numero">2702405</td>,
#  <td class="numero">2702504</td>,
#  <td class="numero">2702553</td>,
#  <td class="numero">2702603</td>,
#  <td class="numero">2702702</td>,
#  <td class="numero">2702801</td>,
#  <td class="numero">2702900</td>,
#  <td class="numero">2703007</td>,
#  <td class="numero">2703106</td>,
#  <td class="numero">2703205</td>,
#  <td class="numero">2703304</td>,
#  <td class="numero">2703403</td>,
#  <td class="numero">2703502</td>,
#  <td class="numero">2703601</td>,
#  <td class="numero">2703700</td>,
#  <td class="numero">2703759</td>,
#  <td class="numero">2703809</td>,
#  <td class="numero">2703908</td>,
#  <td class="numero">2704005</td>,
#  <td class="numero">2704104</td>,
#  <td class="numero">2704203</td>,
#  <td class="numero">2704302</td>,
#  <td class="numero">2704401</td>,
#  <td class="numero">2704906</td>,
#  <td class="numero">2704500</td>,
#  <td class="numero">2704609</td>,
#  <td class="numero">2704708</td>,
#  <td class="numero">2704807</td>,
#  <td class="numero">2705002</td>,
#  <td class="numero">2705101</td>,
#  <td class="numero">2705200</td>,
#  <td class="numero">2705309</td>,
#  <td class="numero">2705408</td>,
#  <td class="numero">2705507</td>,
#  <td class="numero">2705606</td>,
#  <td class="numero">2705903</td>,
#  <td class="numero">2705705</td>,
#  <td class="numero">2705804</td>,
#  <td class="numero">2706000</td>,
#  <td class="numero">2706109</td>,
#  <td class="numero">2706208</td>,
#  <td class="numero">2706307</td>,
#  <td class="numero">2706406</td>,
#  <td class="numero">2706422</td>,
#  <td class="numero">2706448</td>,
#  <td class="numero">2706505</td>,
#  <td class="numero">2706604</td>,
#  <td class="numero">2706703</td>,
#  <td class="numero">2706802</td>,
#  <td class="numero">2706901</td>,
#  <td class="numero">2707008</td>,
#  <td class="numero">2707107</td>,
#  <td class="numero">2707206</td>,
#  <td class="numero">2707305</td>,
#  <td class="numero">2707503</td>,
#  <td class="numero">2707404</td>,
#  <td class="numero">2707602</td>,
#  <td class="numero">2707701</td>,
#  <td class="numero">2707800</td>,
#  <td class="numero">2707909</td>,
#  <td class="numero">2708006</td>,
#  <td class="numero">2708105</td>,
#  <td class="numero">2708204</td>,
#  <td class="numero">2708303</td>,
#  <td class="numero">2708402</td>,
#  <td class="numero">2708501</td>,
#  <td class="numero">2708600</td>,
#  <td class="numero">2708709</td>,
#  <td class="numero">2708808</td>,
#  <td class="numero">2708907</td>,
#  <td class="numero">2708956</td>,
#  <td class="numero">2709004</td>,
#  <td class="numero">2709103</td>,
#  <td class="numero">2709152</td>,
#  <td class="numero">2709202</td>,
#  <td class="numero">2709301</td>,
#  <td class="numero">2709400</td>,
#  <td class="numero">1600105</td>,
#  <td class="numero">1600204</td>,
#  <td class="numero">1600212</td>,
#  <td class="numero">1600238</td>,
#  <td class="numero">1600253</td>,
#  <td class="numero">1600279</td>,
#  <td class="numero">1600303</td>,
#  <td class="numero">1600402</td>,
#  <td class="numero">1600501</td>,
#  <td class="numero">1600154</td>,
#  <td class="numero">1600535</td>,
#  <td class="numero">1600550</td>,
#  <td class="numero">1600600</td>,
#  <td class="numero">1600055</td>,
#  <td class="numero">1600709</td>,
#  <td class="numero">1600808</td>,
#  <td class="numero">1300029</td>,
#  <td class="numero">1300060</td>,
#  <td class="numero">1300086</td>,
#  <td class="numero">1300102</td>,
#  <td class="numero">1300144</td>,
#  <td class="numero">1300201</td>,
#  <td class="numero">1300300</td>,
#  <td class="numero">1300409</td>,
#  <td class="numero">1300508</td>,
#  <td class="numero">1300607</td>,
#  <td class="numero">1300631</td>,
#  <td class="numero">1300680</td>,
#  <td class="numero">1300706</td>,
#  <td class="numero">1300805</td>,
#  <td class="numero">1300839</td>,
#  <td class="numero">1300904</td>,
#  <td class="numero">1301001</td>,
#  <td class="numero">1301100</td>,
#  <td class="numero">1301159</td>,
#  <td class="numero">1301209</td>,
#  <td class="numero">1301308</td>,
#  <td class="numero">1301407</td>,
#  <td class="numero">5207501</td>,
#  <td class="numero">5207535</td>,
#  <td class="numero">5207600</td>,
#  <td class="numero">5207808</td>,
#  <td class="numero">5207907</td>,
#  <td class="numero">5208004</td>,
#  <td class="numero">5208103</td>,
#  <td class="numero">5208152</td>,
#  <td class="numero">5208400</td>,
#  <td class="numero">5208509</td>,
#  <td class="numero">5208608</td>,
#  <td class="numero">5208707</td>,
#  <td class="numero">5208806</td>,
#  <td class="numero">5208905</td>,
#  <td class="numero">5209101</td>,
#  <td class="numero">5209150</td>,
#  <td class="numero">5209200</td>,
#  <td class="numero">5209291</td>,
#  <td class="numero">5209408</td>,
#  <td class="numero">5209457</td>,
#  <td class="numero">5209606</td>,
#  <td class="numero">5209705</td>,
#  <td class="numero">5209804</td>,
#  <td class="numero">5209903</td>,
#  <td class="numero">5209937</td>,
#  <td class="numero">5209952</td>,
#  <td class="numero">5210000</td>,
#  <td class="numero">5210109</td>,
#  <td class="numero">5210158</td>,
#  <td class="numero">5210208</td>,
#  <td class="numero">5210307</td>,
#  <td class="numero">5210406</td>,
#  <td class="numero">5210562</td>,
#  <td class="numero">5210604</td>,
#  <td class="numero">5210802</td>,
#  ...]

# %%
munip = []
for mun in boody_num.find_all('td',{'class': 'numero'})[27:]:
    munip.append(mun.text)

# %%
len(munip)
# Out:
# 5570

# %%
url_api = 'http://www.transparencia.gov.br/api-de-dados/bolsa-familia-por-municipio?mesAno=201902&codigoIbge=3550308&pagina=1'
# Format view
requests.get(url_api).json()
# Out:
# [{'id': 69002750,
#   'dataReferencia': '01/02/2019',
#   'municipio': {'codigoIBGE': '3550308',
#    'nomeIBGE': 'SÃO PAULO',
#    'nomeIBGEsemAcento': 'SAO PAULO',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'SP', 'nome': 'SÃO PAULO'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 73800539.0,
#   'quantidadeBeneficiados': 450885}]

# %%
lst = []

# %%
def gattering(munip,lst,i=0):
    '''
    This function receives a list of municipalities and a empty list,
    making request from a API and in the same time creating a DataFrame to make a bkp into a csv file.
    When getting a error, he will repeat the method after 61 seconds.
    '''
    for pos, mun in enumerate(munip[i:],i):
        print("Municipio: ", mun , 'Lista[' , pos , ']')
        try:
            url_api = f'http://www.transparencia.gov.br/api-de-dados/bolsa-familia-por-municipio?mesAno=201911&codigoIbge={mun}&pagina=1'
            lst.append(requests.get(url_api).json())
            data = pd.DataFrame(lst)
            data.to_csv('dados.csv')
            time.sleep(1)
        except:
            time.sleep(61)
            gattering(munip,lst,pos)
    return lst

# %%
# Gathering the data
# lst_df = gattering(munip,lst,0)

# %%
def flatten(df, col_names):
    
    for col_name in col_names:
        flattened = pd.DataFrame.from_records(df[col_name])
        flattened.columns = [f"{col_name}_{col}" for col in flattened.columns]
        df = pd.concat([df, flattened], axis=1)
        df = df.drop(col_name, axis=1)
        
    return df

# %% [markdown]
# # Bakcup - if needed

# %%
back = pd.read_csv('dados.csv')

# %%
back.drop('Unnamed: 0',axis=1,inplace=True)
back.head()
# Out:
#                                                    0
# 0  {'id': 75202990, 'dataReferencia': '01/11/2019...
# 1  {'id': 69202460, 'dataReferencia': '01/11/2019...
# 2  {'id': 71003156, 'dataReferencia': '01/11/2019...
# 3  {'id': 75803233, 'dataReferencia': '01/11/2019...
# 4  {'id': 67505039, 'dataReferencia': '01/11/2019...

# %%
# Recovering the list format from backup csv
# ast.literal_eval() - recover a string to dictionary - a string with double quotes " "
lst = [item for item in back['0']]
lst_recover = []
for pos, item in enumerate(lst,0):
    if item != 'Error API':
        # here is where I return my data to a json format from a string
        lst_recover.append(ast.literal_eval(item))

# %%
lst_recover
# Out:
# [{'id': 75202990,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '1200013',
#    'nomeIBGE': 'ACRELÂNDIA',
#    'nomeIBGEsemAcento': 'ACRELANDIA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 307671.0,
#   'quantidadeBeneficiados': 1563},
#  {'id': 69202460,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '1200054',
#    'nomeIBGE': 'ASSIS BRASIL',
#    'nomeIBGEsemAcento': 'ASSIS BRASIL',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 443147.0,
#   'quantidadeBeneficiados': 1336},
#  {'id': 71003156,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '1200104',
#    'nomeIBGE': 'BRASILÉIA',
#    'nomeIBGEsemAcento': 'BRASILEIA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 615761.0,
#   'quantidadeBeneficiados': 3030},
#  {'id': 75803233,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '1200138',
#    'nomeIBGE': 'BUJARI',
#    'nomeIBGEsemAcento': 'BUJARI',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 305647.0,
#   'quantidadeBeneficiados': 1326},
#  {'id': 67505039,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '1200179',
#    'nomeIBGE': 'CAPIXABA',
#    'nomeIBGEsemAcento': 'CAPIXABA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 367782.0,
#   'quantidadeBeneficiados': 1444},
#  {'id': 69302315,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '1200203',
#    'nomeIBGE': 'CRUZEIRO DO SUL',
#    'nomeIBGEsemAcento': 'CRUZEIRO DO SUL',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 3357667.0,
#   'quantidadeBeneficiados': 10131},
#  {'id': 67602234,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '1200252',
#    'nomeIBGE': 'EPITACIOLÂNDIA',
#    'nomeIBGEsemAcento': 'EPITACIOLANDIA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 355090.0,
#   'quantidadeBeneficiados': 1659},
#  {'id': 74205461,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '1200302',
#    'nomeIBGE': 'FEIJÓ',
#    'nomeIBGEsemAcento': 'FEIJO',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 1422577.0,
#   'quantidadeBeneficiados': 4574},
#  {'id': 76303912,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '1200328',
#    'nomeIBGE': 'JORDÃO',
#    'nomeIBGEsemAcento': 'JORDAO',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 495942.0,
#   'quantidadeBeneficiados': 1258},
#  {'id': 65602695,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '1200336',
#    'nomeIBGE': 'MÂNCIO LIMA',
#    'nomeIBGEsemAcento': 'MANCIO LIMA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 1080155.0,
#   'quantidadeBeneficiados': 3074},
#  {'id': 62904887,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '1200344',
#    'nomeIBGE': 'MANOEL URBANO',
#    'nomeIBGEsemAcento': 'MANOEL URBANO',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 581350.0,
#   'quantidadeBeneficiados': 1684},
#  {'id': 66304642,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '1200351',
#    'nomeIBGE': 'MARECHAL THAUMATURGO',
#    'nomeIBGEsemAcento': 'MARECHAL THAUMATURGO',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 852171.0,
#   'quantidadeBeneficiados': 2658},
#  {'id': 66102422,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '1200385',
#    'nomeIBGE': 'PLÁCIDO DE CASTRO',
#    'nomeIBGEsemAcento': 'PLACIDO DE CASTRO',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 266134.0,
#   'quantidadeBeneficiados': 1449},
#  {'id': 67104567,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '1200807',
#    'nomeIBGE': 'PORTO ACRE',
#    'nomeIBGEsemAcento': 'PORTO ACRE',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 581937.0,
#   'quantidadeBeneficiados': 2554},
#  {'id': 74903626,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '1200393',
#    'nomeIBGE': 'PORTO WALTER',
#    'nomeIBGEsemAcento': 'PORTO WALTER',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 492542.0,
#   'quantidadeBeneficiados': 1473},
#  {'id': 65802364,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '1200401',
#    'nomeIBGE': 'RIO BRANCO',
#    'nomeIBGEsemAcento': 'RIO BRANCO',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 5123393.0,
#   'quantidadeBeneficiados': 20802},
#  {'id': 71002873,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '1200427',
#    'nomeIBGE': 'RODRIGUES ALVES',
#    'nomeIBGEsemAcento': 'RODRIGUES ALVES',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 736385.0,
#   'quantidadeBeneficiados': 2360},
#  {'id': 66603584,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '1200435',
#    'nomeIBGE': 'SANTA ROSA DO PURUS',
#    'nomeIBGEsemAcento': 'SANTA ROSA DO PURUS',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 423152.0,
#   'quantidadeBeneficiados': 1031},
#  {'id': 71302808,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '1200500',
#    'nomeIBGE': 'SENA MADUREIRA',
#    'nomeIBGEsemAcento': 'SENA MADUREIRA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 1977950.0,
#   'quantidadeBeneficiados': 6624},
#  {'id': 64304905,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '1200450',
#    'nomeIBGE': 'SENADOR GUIOMARD',
#    'nomeIBGEsemAcento': 'SENADOR GUIOMARD',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 1048032.0,
#   'quantidadeBeneficiados': 3849},
#  {'id': 73303704,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '1200609',
#    'nomeIBGE': 'TARAUACÁ',
#    'nomeIBGEsemAcento': 'TARAUACA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 2548146.0,
#   'quantidadeBeneficiados': 6956},
#  {'id': 62904919,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '1200708',
#    'nomeIBGE': 'XAPURI',
#    'nomeIBGEsemAcento': 'XAPURI',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 396041.0,
#   'quantidadeBeneficiados': 1919},
#  {'id': 68602487,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2700102',
#    'nomeIBGE': 'ÁGUA BRANCA',
#    'nomeIBGEsemAcento': 'AGUA BRANCA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 851437.0,
#   'quantidadeBeneficiados': 2767},
#  {'id': 67302958,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2700201',
#    'nomeIBGE': 'ANADIA',
#    'nomeIBGEsemAcento': 'ANADIA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 458752.0,
#   'quantidadeBeneficiados': 2534},
#  {'id': 66302386,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2700300',
#    'nomeIBGE': 'ARAPIRACA',
#    'nomeIBGEsemAcento': 'ARAPIRACA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 3386638.0,
#   'quantidadeBeneficiados': 17762},
#  {'id': 63204514,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2700409',
#    'nomeIBGE': 'ATALAIA',
#    'nomeIBGEsemAcento': 'ATALAIA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 1375879.0,
#   'quantidadeBeneficiados': 7197},
#  {'id': 68102881,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2700508',
#    'nomeIBGE': 'BARRA DE SANTO ANTÔNIO',
#    'nomeIBGEsemAcento': 'BARRA DE SANTO ANTONIO',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 705144.0,
#   'quantidadeBeneficiados': 3741},
#  {'id': 76603429,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2700607',
#    'nomeIBGE': 'BARRA DE SÃO MIGUEL',
#    'nomeIBGEsemAcento': 'BARRA DE SAO MIGUEL',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 247289.0,
#   'quantidadeBeneficiados': 1174},
#  {'id': 66804181,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2700706',
#    'nomeIBGE': 'BATALHA',
#    'nomeIBGEsemAcento': 'BATALHA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 732284.0,
#   'quantidadeBeneficiados': 3154},
#  {'id': 68605061,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2700805',
#    'nomeIBGE': 'BELÉM',
#    'nomeIBGEsemAcento': 'BELEM',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 181881.0,
#   'quantidadeBeneficiados': 839},
#  {'id': 69402244,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2700904',
#    'nomeIBGE': 'BELO MONTE',
#    'nomeIBGEsemAcento': 'BELO MONTE',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 308265.0,
#   'quantidadeBeneficiados': 1259},
#  {'id': 64903073,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2701001',
#    'nomeIBGE': 'BOCA DA MATA',
#    'nomeIBGEsemAcento': 'BOCA DA MATA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 746041.0,
#   'quantidadeBeneficiados': 3485},
#  {'id': 65703388,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2701100',
#    'nomeIBGE': 'BRANQUINHA',
#    'nomeIBGEsemAcento': 'BRANQUINHA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 317805.0,
#   'quantidadeBeneficiados': 1857},
#  {'id': 65403691,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2701209',
#    'nomeIBGE': 'CACIMBINHAS',
#    'nomeIBGEsemAcento': 'CACIMBINHAS',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 441611.0,
#   'quantidadeBeneficiados': 1946},
#  {'id': 71803264,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2701308',
#    'nomeIBGE': 'CAJUEIRO',
#    'nomeIBGEsemAcento': 'CAJUEIRO',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 590116.0,
#   'quantidadeBeneficiados': 3273},
#  {'id': 72202885,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2701357',
#    'nomeIBGE': 'CAMPESTRE',
#    'nomeIBGEsemAcento': 'CAMPESTRE',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 271222.0,
#   'quantidadeBeneficiados': 1373},
#  {'id': 69604398,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2701407',
#    'nomeIBGE': 'CAMPO ALEGRE',
#    'nomeIBGEsemAcento': 'CAMPO ALEGRE',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 891954.0,
#   'quantidadeBeneficiados': 5543},
#  {'id': 68902813,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2701506',
#    'nomeIBGE': 'CAMPO GRANDE',
#    'nomeIBGEsemAcento': 'CAMPO GRANDE',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 630795.0,
#   'quantidadeBeneficiados': 2215},
#  {'id': 70804777,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2701605',
#    'nomeIBGE': 'CANAPI',
#    'nomeIBGEsemAcento': 'CANAPI',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 1143155.0,
#   'quantidadeBeneficiados': 4114},
#  {'id': 72604916,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2701704',
#    'nomeIBGE': 'CAPELA',
#    'nomeIBGEsemAcento': 'CAPELA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 426397.0,
#   'quantidadeBeneficiados': 2074},
#  {'id': 76003899,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2701803',
#    'nomeIBGE': 'CARNEIROS',
#    'nomeIBGEsemAcento': 'CARNEIROS',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 491516.0,
#   'quantidadeBeneficiados': 1665},
#  {'id': 73904508,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2701902',
#    'nomeIBGE': 'CHÃ PRETA',
#    'nomeIBGEsemAcento': 'CHA PRETA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 335554.0,
#   'quantidadeBeneficiados': 1171},
#  {'id': 63004620,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2702009',
#    'nomeIBGE': 'COITÉ DO NÓIA',
#    'nomeIBGEsemAcento': 'COITE DO NOIA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 310497.0,
#   'quantidadeBeneficiados': 1435},
#  {'id': 67105139,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2702108',
#    'nomeIBGE': 'COLÔNIA LEOPOLDINA',
#    'nomeIBGEsemAcento': 'COLONIA LEOPOLDINA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 817811.0,
#   'quantidadeBeneficiados': 3983},
#  {'id': 75004539,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2702207',
#    'nomeIBGE': 'COQUEIRO SECO',
#    'nomeIBGEsemAcento': 'COQUEIRO SECO',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 114179.0,
#   'quantidadeBeneficiados': 664},
#  {'id': 75602355,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2702306',
#    'nomeIBGE': 'CORURIPE',
#    'nomeIBGEsemAcento': 'CORURIPE',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 866185.0,
#   'quantidadeBeneficiados': 4883},
#  {'id': 76504682,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2702355',
#    'nomeIBGE': 'CRAÍBAS',
#    'nomeIBGEsemAcento': 'CRAIBAS',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 968656.0,
#   'quantidadeBeneficiados': 3603},
#  {'id': 64602708,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2702405',
#    'nomeIBGE': 'DELMIRO GOUVEIA',
#    'nomeIBGEsemAcento': 'DELMIRO GOUVEIA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 1188387.0,
#   'quantidadeBeneficiados': 5896},
#  {'id': 66004945,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2702504',
#    'nomeIBGE': 'DOIS RIACHOS',
#    'nomeIBGEsemAcento': 'DOIS RIACHOS',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 276525.0,
#   'quantidadeBeneficiados': 1763},
#  {'id': 66904724,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2702553',
#    'nomeIBGE': 'ESTRELA DE ALAGOAS',
#    'nomeIBGEsemAcento': 'ESTRELA DE ALAGOAS',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 576903.0,
#   'quantidadeBeneficiados': 2386},
#  {'id': 68303597,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2702603',
#    'nomeIBGE': 'FEIRA GRANDE',
#    'nomeIBGEsemAcento': 'FEIRA GRANDE',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 850380.0,
#   'quantidadeBeneficiados': 4035},
#  {'id': 70902589,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2702702',
#    'nomeIBGE': 'FELIZ DESERTO',
#    'nomeIBGEsemAcento': 'FELIZ DESERTO',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 99824.0,
#   'quantidadeBeneficiados': 624},
#  {'id': 65303877,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2702801',
#    'nomeIBGE': 'FLEXEIRAS',
#    'nomeIBGEsemAcento': 'FLEXEIRAS',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 398250.0,
#   'quantidadeBeneficiados': 2029},
#  {'id': 67504277,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2702900',
#    'nomeIBGE': 'GIRAU DO PONCIANO',
#    'nomeIBGEsemAcento': 'GIRAU DO PONCIANO',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 1501454.0,
#   'quantidadeBeneficiados': 5397},
#  {'id': 63204648,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2703007',
#    'nomeIBGE': 'IBATEGUARA',
#    'nomeIBGEsemAcento': 'IBATEGUARA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 472593.0,
#   'quantidadeBeneficiados': 2242},
#  {'id': 69502720,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2703106',
#    'nomeIBGE': 'IGACI',
#    'nomeIBGEsemAcento': 'IGACI',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 1206315.0,
#   'quantidadeBeneficiados': 4589},
#  {'id': 71702291,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2703205',
#    'nomeIBGE': 'IGREJA NOVA',
#    'nomeIBGEsemAcento': 'IGREJA NOVA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 540666.0,
#   'quantidadeBeneficiados': 3214},
#  {'id': 62403058,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2703304',
#    'nomeIBGE': 'INHAPI',
#    'nomeIBGEsemAcento': 'INHAPI',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 616959.0,
#   'quantidadeBeneficiados': 2577},
#  {'id': 64605080,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2703403',
#    'nomeIBGE': 'JACARÉ DOS HOMENS',
#    'nomeIBGEsemAcento': 'JACARE DOS HOMENS',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 207384.0,
#   'quantidadeBeneficiados': 1085},
#  {'id': 76502462,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2703502',
#    'nomeIBGE': 'JACUÍPE',
#    'nomeIBGEsemAcento': 'JACUIPE',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 165784.0,
#   'quantidadeBeneficiados': 1025},
#  {'id': 73905017,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2703601',
#    'nomeIBGE': 'JAPARATINGA',
#    'nomeIBGEsemAcento': 'JAPARATINGA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 363361.0,
#   'quantidadeBeneficiados': 1775},
#  {'id': 62602832,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2703700',
#    'nomeIBGE': 'JARAMATAIA',
#    'nomeIBGEsemAcento': 'JARAMATAIA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 226405.0,
#   'quantidadeBeneficiados': 936},
#  {'id': 65904611,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2703759',
#    'nomeIBGE': 'JEQUIÁ DA PRAIA',
#    'nomeIBGEsemAcento': 'JEQUIA DA PRAIA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 494463.0,
#   'quantidadeBeneficiados': 2092},
#  {'id': 64302723,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2703809',
#    'nomeIBGE': 'JOAQUIM GOMES',
#    'nomeIBGEsemAcento': 'JOAQUIM GOMES',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 561955.0,
#   'quantidadeBeneficiados': 3169},
#  {'id': 72703209,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2703908',
#    'nomeIBGE': 'JUNDIÁ',
#    'nomeIBGEsemAcento': 'JUNDIA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 188324.0,
#   'quantidadeBeneficiados': 719},
#  {'id': 65603301,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2704005',
#    'nomeIBGE': 'JUNQUEIRO',
#    'nomeIBGEsemAcento': 'JUNQUEIRO',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 630584.0,
#   'quantidadeBeneficiados': 3629},
#  {'id': 73103443,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2704104',
#    'nomeIBGE': 'LAGOA DA CANOA',
#    'nomeIBGEsemAcento': 'LAGOA DA CANOA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 708681.0,
#   'quantidadeBeneficiados': 2928},
#  {'id': 62803733,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2704203',
#    'nomeIBGE': 'LIMOEIRO DE ANADIA',
#    'nomeIBGEsemAcento': 'LIMOEIRO DE ANADIA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 947633.0,
#   'quantidadeBeneficiados': 3851},
#  {'id': 66403597,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2704302',
#    'nomeIBGE': 'MACEIÓ',
#    'nomeIBGEsemAcento': 'MACEIO',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 8805285.0,
#   'quantidadeBeneficiados': 50585},
#  {'id': 66103686,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2704401',
#    'nomeIBGE': 'MAJOR ISIDORO',
#    'nomeIBGEsemAcento': 'MAJOR ISIDORO',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 704572.0,
#   'quantidadeBeneficiados': 3145},
#  {'id': 69704250,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2704906',
#    'nomeIBGE': 'MAR VERMELHO',
#    'nomeIBGEsemAcento': 'MAR VERMELHO',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 139647.0,
#   'quantidadeBeneficiados': 617},
#  {'id': 76704515,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2704500',
#    'nomeIBGE': 'MARAGOGI',
#    'nomeIBGEsemAcento': 'MARAGOGI',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 864225.0,
#   'quantidadeBeneficiados': 4656},
#  {'id': 67805017,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2704609',
#    'nomeIBGE': 'MARAVILHA',
#    'nomeIBGEsemAcento': 'MARAVILHA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 496400.0,
#   'quantidadeBeneficiados': 2624},
#  {'id': 70402451,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2704708',
#    'nomeIBGE': 'MARECHAL DEODORO',
#    'nomeIBGEsemAcento': 'MARECHAL DEODORO',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 1406713.0,
#   'quantidadeBeneficiados': 6604},
#  {'id': 63404311,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2704807',
#    'nomeIBGE': 'MARIBONDO',
#    'nomeIBGEsemAcento': 'MARIBONDO',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 332776.0,
#   'quantidadeBeneficiados': 1815},
#  {'id': 71304838,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2705002',
#    'nomeIBGE': 'MATA GRANDE',
#    'nomeIBGEsemAcento': 'MATA GRANDE',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 702559.0,
#   'quantidadeBeneficiados': 3343},
#  {'id': 66104417,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2705101',
#    'nomeIBGE': 'MATRIZ DE CAMARAGIBE',
#    'nomeIBGEsemAcento': 'MATRIZ DE CAMARAGIBE',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 590298.0,
#   'quantidadeBeneficiados': 3259},
#  {'id': 71705212,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2705200',
#    'nomeIBGE': 'MESSIAS',
#    'nomeIBGEsemAcento': 'MESSIAS',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 277950.0,
#   'quantidadeBeneficiados': 1556},
#  {'id': 64902176,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2705309',
#    'nomeIBGE': 'MINADOR DO NEGRÃO',
#    'nomeIBGEsemAcento': 'MINADOR DO NEGRAO',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 182751.0,
#   'quantidadeBeneficiados': 692},
#  {'id': 69703380,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2705408',
#    'nomeIBGE': 'MONTEIRÓPOLIS',
#    'nomeIBGEsemAcento': 'MONTEIROPOLIS',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 352295.0,
#   'quantidadeBeneficiados': 1509},
#  {'id': 68104003,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2705507',
#    'nomeIBGE': 'MURICI',
#    'nomeIBGEsemAcento': 'MURICI',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 823774.0,
#   'quantidadeBeneficiados': 3842},
#  {'id': 70403004,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2705606',
#    'nomeIBGE': 'NOVO LINO',
#    'nomeIBGEsemAcento': 'NOVO LINO',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 380079.0,
#   'quantidadeBeneficiados': 1839},
#  {'id': 70104451,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2705903',
#    'nomeIBGE': "OLHO D'ÁGUA GRANDE",
#    'nomeIBGEsemAcento': "OLHO D'AGUA GRANDE",
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 370155.0,
#   'quantidadeBeneficiados': 1299},
#  {'id': 65002659,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2705705',
#    'nomeIBGE': "OLHO D'ÁGUA DAS FLORES",
#    'nomeIBGEsemAcento': "OLHO D'AGUA DAS FLORES",
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 418964.0,
#   'quantidadeBeneficiados': 2611},
#  {'id': 67702550,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2705804',
#    'nomeIBGE': "OLHO D'ÁGUA DO CASADO",
#    'nomeIBGEsemAcento': "OLHO D'AGUA DO CASADO",
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 400950.0,
#   'quantidadeBeneficiados': 1646},
#  {'id': 67602378,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2706000',
#    'nomeIBGE': 'OLIVENÇA',
#    'nomeIBGEsemAcento': 'OLIVENCA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 569683.0,
#   'quantidadeBeneficiados': 2012},
#  {'id': 68703275,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2706109',
#    'nomeIBGE': 'OURO BRANCO',
#    'nomeIBGEsemAcento': 'OURO BRANCO',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 564860.0,
#   'quantidadeBeneficiados': 2479},
#  {'id': 71603238,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2706208',
#    'nomeIBGE': 'PALESTINA',
#    'nomeIBGEsemAcento': 'PALESTINA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 161013.0,
#   'quantidadeBeneficiados': 841},
#  {'id': 75403795,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2706307',
#    'nomeIBGE': 'PALMEIRA DOS ÍNDIOS',
#    'nomeIBGEsemAcento': 'PALMEIRA DOS INDIOS',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 1917599.0,
#   'quantidadeBeneficiados': 10220},
#  {'id': 74703848,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2706406',
#    'nomeIBGE': 'PÃO DE AÇÚCAR',
#    'nomeIBGEsemAcento': 'PAO DE ACUCAR',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 575350.0,
#   'quantidadeBeneficiados': 3444},
#  {'id': 68204004,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2706422',
#    'nomeIBGE': 'PARICONHA',
#    'nomeIBGEsemAcento': 'PARICONHA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 430998.0,
#   'quantidadeBeneficiados': 1678},
#  {'id': 64304750,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2706448',
#    'nomeIBGE': 'PARIPUEIRA',
#    'nomeIBGEsemAcento': 'PARIPUEIRA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 360005.0,
#   'quantidadeBeneficiados': 2070},
#  {'id': 67604327,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2706505',
#    'nomeIBGE': 'PASSO DE CAMARAGIBE',
#    'nomeIBGEsemAcento': 'PASSO DE CAMARAGIBE',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 365737.0,
#   'quantidadeBeneficiados': 1927},
#  {'id': 64303794,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2706604',
#    'nomeIBGE': 'PAULO JACINTO',
#    'nomeIBGEsemAcento': 'PAULO JACINTO',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 236147.0,
#   'quantidadeBeneficiados': 1234},
#  {'id': 70604234,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2706703',
#    'nomeIBGE': 'PENEDO',
#    'nomeIBGEsemAcento': 'PENEDO',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 1794968.0,
#   'quantidadeBeneficiados': 9340},
#  {'id': 67804743,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2706802',
#    'nomeIBGE': 'PIAÇABUÇU',
#    'nomeIBGEsemAcento': 'PIACABUCU',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 838147.0,
#   'quantidadeBeneficiados': 3954},
#  {'id': 76302204,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2706901',
#    'nomeIBGE': 'PILAR',
#    'nomeIBGEsemAcento': 'PILAR',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 919130.0,
#   'quantidadeBeneficiados': 5083},
#  {'id': 67502507,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2707008',
#    'nomeIBGE': 'PINDOBA',
#    'nomeIBGEsemAcento': 'PINDOBA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 71821.0,
#   'quantidadeBeneficiados': 299},
#  {'id': 63404756,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2707107',
#    'nomeIBGE': 'PIRANHAS',
#    'nomeIBGEsemAcento': 'PIRANHAS',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 882336.0,
#   'quantidadeBeneficiados': 3666},
#  {'id': 69603314,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2707206',
#    'nomeIBGE': 'POÇO DAS TRINCHEIRAS',
#    'nomeIBGEsemAcento': 'POCO DAS TRINCHEIRAS',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 666304.0,
#   'quantidadeBeneficiados': 2383},
#  {'id': 63902457,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2707305',
#    'nomeIBGE': 'PORTO CALVO',
#    'nomeIBGEsemAcento': 'PORTO CALVO',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 872899.0,
#   'quantidadeBeneficiados': 5214},
#  {'id': 72202867,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2707503',
#    'nomeIBGE': 'PORTO REAL DO COLÉGIO',
#    'nomeIBGEsemAcento': 'PORTO REAL DO COLEGIO',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 903046.0,
#   'quantidadeBeneficiados': 3811},
#  {'id': 69005141,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2707404',
#    'nomeIBGE': 'PORTO DE PEDRAS',
#    'nomeIBGEsemAcento': 'PORTO DE PEDRAS',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 287342.0,
#   'quantidadeBeneficiados': 1611},
#  {'id': 63903429,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2707602',
#    'nomeIBGE': 'QUEBRANGULO',
#    'nomeIBGEsemAcento': 'QUEBRANGULO',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 604128.0,
#   'quantidadeBeneficiados': 2221},
#  {'id': 67202951,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2707701',
#    'nomeIBGE': 'RIO LARGO',
#    'nomeIBGEsemAcento': 'RIO LARGO',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 1679483.0,
#   'quantidadeBeneficiados': 9766},
#  {'id': 63504092,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2707800',
#    'nomeIBGE': 'ROTEIRO',
#    'nomeIBGEsemAcento': 'ROTEIRO',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 240809.0,
#   'quantidadeBeneficiados': 1148},
#  {'id': 70603024,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2707909',
#    'nomeIBGE': 'SANTA LUZIA DO NORTE',
#    'nomeIBGEsemAcento': 'SANTA LUZIA DO NORTE',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 157329.0,
#   'quantidadeBeneficiados': 805},
#  {'id': 70504159,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2708006',
#    'nomeIBGE': 'SANTANA DO IPANEMA',
#    'nomeIBGEsemAcento': 'SANTANA DO IPANEMA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 1762686.0,
#   'quantidadeBeneficiados': 7543},
#  {'id': 69203597,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2708105',
#    'nomeIBGE': 'SANTANA DO MUNDAÚ',
#    'nomeIBGEsemAcento': 'SANTANA DO MUNDAU',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 294946.0,
#   'quantidadeBeneficiados': 1698},
#  {'id': 75803612,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2708204',
#    'nomeIBGE': 'SÃO BRÁS',
#    'nomeIBGEsemAcento': 'SAO BRAS',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 222660.0,
#   'quantidadeBeneficiados': 1016},
#  {'id': 74804615,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2708303',
#    'nomeIBGE': 'SÃO JOSÉ DA LAJE',
#    'nomeIBGEsemAcento': 'SAO JOSE DA LAJE',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 587222.0,
#   'quantidadeBeneficiados': 3103},
#  {'id': 75404459,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2708402',
#    'nomeIBGE': 'SÃO JOSÉ DA TAPERA',
#    'nomeIBGEsemAcento': 'SAO JOSE DA TAPERA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 1556931.0,
#   'quantidadeBeneficiados': 5943},
#  {'id': 65904876,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2708501',
#    'nomeIBGE': 'SÃO LUÍS DO QUITUNDE',
#    'nomeIBGEsemAcento': 'SAO LUIS DO QUITUNDE',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 1017676.0,
#   'quantidadeBeneficiados': 6077},
#  {'id': 76305269,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2708600',
#    'nomeIBGE': 'SÃO MIGUEL DOS CAMPOS',
#    'nomeIBGEsemAcento': 'SAO MIGUEL DOS CAMPOS',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 1255646.0,
#   'quantidadeBeneficiados': 7271},
#  {'id': 62702446,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2708709',
#    'nomeIBGE': 'SÃO MIGUEL DOS MILAGRES',
#    'nomeIBGEsemAcento': 'SAO MIGUEL DOS MILAGRES',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 204655.0,
#   'quantidadeBeneficiados': 1190},
#  {'id': 74704457,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2708808',
#    'nomeIBGE': 'SÃO SEBASTIÃO',
#    'nomeIBGEsemAcento': 'SAO SEBASTIAO',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 1294001.0,
#   'quantidadeBeneficiados': 5518},
#  {'id': 62604166,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2708907',
#    'nomeIBGE': 'SATUBA',
#    'nomeIBGEsemAcento': 'SATUBA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 313093.0,
#   'quantidadeBeneficiados': 1475},
#  {'id': 75704054,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2708956',
#    'nomeIBGE': 'SENADOR RUI PALMEIRA',
#    'nomeIBGEsemAcento': 'SENADOR RUI PALMEIRA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 568669.0,
#   'quantidadeBeneficiados': 2198},
#  {'id': 63905117,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2709004',
#    'nomeIBGE': "TANQUE D'ARCA",
#    'nomeIBGEsemAcento': "TANQUE D'ARCA",
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 215628.0,
#   'quantidadeBeneficiados': 984},
#  {'id': 69702044,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2709103',
#    'nomeIBGE': 'TAQUARANA',
#    'nomeIBGEsemAcento': 'TAQUARANA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 485042.0,
#   'quantidadeBeneficiados': 2388},
#  {'id': 72704907,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2709152',
#    'nomeIBGE': 'TEOTÔNIO VILELA',
#    'nomeIBGEsemAcento': 'TEOTONIO VILELA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 955041.0,
#   'quantidadeBeneficiados': 4837},
#  {'id': 67102442,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2709202',
#    'nomeIBGE': 'TRAIPU',
#    'nomeIBGEsemAcento': 'TRAIPU',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 931466.0,
#   'quantidadeBeneficiados': 3595},
#  {'id': 67003074,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2709301',
#    'nomeIBGE': 'UNIÃO DOS PALMARES',
#    'nomeIBGEsemAcento': 'UNIAO DOS PALMARES',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 1403070.0,
#   'quantidadeBeneficiados': 8729},
#  {'id': 68303946,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '2709400',
#    'nomeIBGE': 'VIÇOSA',
#    'nomeIBGEsemAcento': 'VICOSA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 788906.0,
#   'quantidadeBeneficiados': 3891},
#  {'id': 76604065,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '1600105',
#    'nomeIBGE': 'AMAPÁ',
#    'nomeIBGEsemAcento': 'AMAPA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'AP', 'nome': 'AMAPÁ'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 512873.0,
#   'quantidadeBeneficiados': 1991},
#  {'id': 73004370,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '1600204',
#    'nomeIBGE': 'CALÇOENE',
#    'nomeIBGEsemAcento': 'CALCOENE',
#    'pais': 'BRASIL',
# ...
#    'nomeIBGEsemAcento': 'DAMIANOPOLIS',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 97260.0,
#   'quantidadeBeneficiados': 493},
#  {'id': 64605176,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5206800',
#    'nomeIBGE': 'DAMOLÂNDIA',
#    'nomeIBGEsemAcento': 'DAMOLANDIA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 34424.0,
#   'quantidadeBeneficiados': 237},
#  {'id': 69402400,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5206909',
#    'nomeIBGE': 'DAVINÓPOLIS',
#    'nomeIBGEsemAcento': 'DAVINOPOLIS',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 13045.0,
#   'quantidadeBeneficiados': 93},
#  {'id': 67602794,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5207105',
#    'nomeIBGE': 'DIORAMA',
#    'nomeIBGEsemAcento': 'DIORAMA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 22764.0,
#   'quantidadeBeneficiados': 152},
#  {'id': 63603891,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5208301',
#    'nomeIBGE': 'DIVINÓPOLIS DE GOIÁS',
#    'nomeIBGEsemAcento': 'DIVINOPOLIS DE GOIAS',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 168830.0,
#   'quantidadeBeneficiados': 887},
#  {'id': 75003318,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5207253',
#    'nomeIBGE': 'DOVERLÂNDIA',
#    'nomeIBGEsemAcento': 'DOVERLANDIA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 115722.0,
#   'quantidadeBeneficiados': 602},
#  {'id': 63703133,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5207352',
#    'nomeIBGE': 'EDEALINA',
#    'nomeIBGEsemAcento': 'EDEALINA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 32900.0,
#   'quantidadeBeneficiados': 189},
#  {'id': 67603627,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5207402',
#    'nomeIBGE': 'EDÉIA',
#    'nomeIBGEsemAcento': 'EDEIA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 148079.0,
#   'quantidadeBeneficiados': 825},
#  {'id': 68402680,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5207501',
#    'nomeIBGE': 'ESTRELA DO NORTE',
#    'nomeIBGEsemAcento': 'ESTRELA DO NORTE',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 37507.0,
#   'quantidadeBeneficiados': 215},
#  {'id': 62402425,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5207535',
#    'nomeIBGE': 'FAINA',
#    'nomeIBGEsemAcento': 'FAINA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 85915.0,
#   'quantidadeBeneficiados': 519},
#  {'id': 64703880,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5207600',
#    'nomeIBGE': 'FAZENDA NOVA',
#    'nomeIBGEsemAcento': 'FAZENDA NOVA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 131695.0,
#   'quantidadeBeneficiados': 629},
#  {'id': 70604987,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5207808',
#    'nomeIBGE': 'FIRMINÓPOLIS',
#    'nomeIBGEsemAcento': 'FIRMINOPOLIS',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 82517.0,
#   'quantidadeBeneficiados': 535},
#  {'id': 72902351,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5207907',
#    'nomeIBGE': 'FLORES DE GOIÁS',
#    'nomeIBGEsemAcento': 'FLORES DE GOIAS',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 220028.0,
#   'quantidadeBeneficiados': 1272},
#  {'id': 63002795,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5208004',
#    'nomeIBGE': 'FORMOSA',
#    'nomeIBGEsemAcento': 'FORMOSA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 1176248.0,
#   'quantidadeBeneficiados': 6475},
#  {'id': 74903911,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5208103',
#    'nomeIBGE': 'FORMOSO',
#    'nomeIBGEsemAcento': 'FORMOSO',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 84816.0,
#   'quantidadeBeneficiados': 538},
#  {'id': 72304359,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5208152',
#    'nomeIBGE': 'GAMELEIRA DE GOIÁS',
#    'nomeIBGEsemAcento': 'GAMELEIRA DE GOIAS',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 23542.0,
#   'quantidadeBeneficiados': 140},
#  {'id': 75703406,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5208400',
#    'nomeIBGE': 'GOIANÁPOLIS',
#    'nomeIBGEsemAcento': 'GOIANAPOLIS',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 132631.0,
#   'quantidadeBeneficiados': 978},
#  {'id': 64004368,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5208509',
#    'nomeIBGE': 'GOIANDIRA',
#    'nomeIBGEsemAcento': 'GOIANDIRA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 28515.0,
#   'quantidadeBeneficiados': 198},
#  {'id': 64304498,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5208608',
#    'nomeIBGE': 'GOIANÉSIA',
#    'nomeIBGEsemAcento': 'GOIANESIA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 329795.0,
#   'quantidadeBeneficiados': 1941},
#  {'id': 67904436,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5208707',
#    'nomeIBGE': 'GOIÂNIA',
#    'nomeIBGEsemAcento': 'GOIANIA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 3630371.0,
#   'quantidadeBeneficiados': 22017},
#  {'id': 65904892,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5208806',
#    'nomeIBGE': 'GOIANIRA',
#    'nomeIBGEsemAcento': 'GOIANIRA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 338068.0,
#   'quantidadeBeneficiados': 1904},
#  {'id': 62903742,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5208905',
#    'nomeIBGE': 'GOIÁS',
#    'nomeIBGEsemAcento': 'GOIAS',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 194250.0,
#   'quantidadeBeneficiados': 1156},
#  {'id': 72904424,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5209101',
#    'nomeIBGE': 'GOIATUBA',
#    'nomeIBGEsemAcento': 'GOIATUBA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 154211.0,
#   'quantidadeBeneficiados': 1011},
#  {'id': 71904910,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5209150',
#    'nomeIBGE': 'GOUVELÂNDIA',
#    'nomeIBGEsemAcento': 'GOUVELANDIA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 22847.0,
#   'quantidadeBeneficiados': 150},
#  {'id': 75402524,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5209200',
#    'nomeIBGE': 'GUAPÓ',
#    'nomeIBGEsemAcento': 'GUAPO',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 256908.0,
#   'quantidadeBeneficiados': 1534},
#  {'id': 76002897,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5209291',
#    'nomeIBGE': 'GUARAÍTA',
#    'nomeIBGEsemAcento': 'GUARAITA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 34339.0,
#   'quantidadeBeneficiados': 230},
#  {'id': 65503837,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5209408',
#    'nomeIBGE': 'GUARANI DE GOIÁS',
#    'nomeIBGEsemAcento': 'GUARANI DE GOIAS',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 118882.0,
#   'quantidadeBeneficiados': 511},
#  {'id': 76304609,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5209457',
#    'nomeIBGE': 'GUARINOS',
#    'nomeIBGEsemAcento': 'GUARINOS',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 33904.0,
#   'quantidadeBeneficiados': 258},
#  {'id': 64802781,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5209606',
#    'nomeIBGE': 'HEITORAÍ',
#    'nomeIBGEsemAcento': 'HEITORAI',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 64059.0,
#   'quantidadeBeneficiados': 441},
#  {'id': 63203151,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5209705',
#    'nomeIBGE': 'HIDROLÂNDIA',
#    'nomeIBGEsemAcento': 'HIDROLANDIA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 127856.0,
#   'quantidadeBeneficiados': 819},
#  {'id': 64904606,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5209804',
#    'nomeIBGE': 'HIDROLINA',
#    'nomeIBGEsemAcento': 'HIDROLINA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 36519.0,
#   'quantidadeBeneficiados': 253},
#  {'id': 75002299,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5209903',
#    'nomeIBGE': 'IACIARA',
#    'nomeIBGEsemAcento': 'IACIARA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 293134.0,
#   'quantidadeBeneficiados': 1573},
#  {'id': 74004766,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5209952',
#    'nomeIBGE': 'INDIARA',
#    'nomeIBGEsemAcento': 'INDIARA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 117454.0,
#   'quantidadeBeneficiados': 774},
#  {'id': 68402880,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5210000',
#    'nomeIBGE': 'INHUMAS',
#    'nomeIBGEsemAcento': 'INHUMAS',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 307067.0,
#   'quantidadeBeneficiados': 1876},
#  {'id': 69105048,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5210109',
#    'nomeIBGE': 'IPAMERI',
#    'nomeIBGEsemAcento': 'IPAMERI',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 274695.0,
#   'quantidadeBeneficiados': 1434},
#  {'id': 69704286,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5210158',
#    'nomeIBGE': 'IPIRANGA DE GOIÁS',
#    'nomeIBGEsemAcento': 'IPIRANGA DE GOIAS',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 41098.0,
#   'quantidadeBeneficiados': 285},
#  {'id': 65903756,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5210208',
#    'nomeIBGE': 'IPORÁ',
#    'nomeIBGEsemAcento': 'IPORA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 63240.0,
#   'quantidadeBeneficiados': 490},
#  {'id': 65602517,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5210307',
#    'nomeIBGE': 'ISRAELÂNDIA',
#    'nomeIBGEsemAcento': 'ISRAELANDIA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 20347.0,
#   'quantidadeBeneficiados': 126},
#  {'id': 66404121,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5210406',
#    'nomeIBGE': 'ITABERAÍ',
#    'nomeIBGEsemAcento': 'ITABERAI',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 399936.0,
#   'quantidadeBeneficiados': 2654},
#  {'id': 69103435,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5210562',
#    'nomeIBGE': 'ITAGUARI',
#    'nomeIBGEsemAcento': 'ITAGUARI',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 41951.0,
#   'quantidadeBeneficiados': 292},
#  {'id': 75005076,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5210604',
#    'nomeIBGE': 'ITAGUARU',
#    'nomeIBGEsemAcento': 'ITAGUARU',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 54297.0,
#   'quantidadeBeneficiados': 358},
#  {'id': 66203403,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5210802',
#    'nomeIBGE': 'ITAJÁ',
#    'nomeIBGEsemAcento': 'ITAJA',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 38541.0,
#   'quantidadeBeneficiados': 216},
#  {'id': 69403921,
#   'dataReferencia': '01/11/2019',
#   'municipio': {'codigoIBGE': '5210901',
#    'nomeIBGE': 'ITAPACI',
#    'nomeIBGEsemAcento': 'ITAPACI',
#    'pais': 'BRASIL',
#    'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#   'tipo': {'id': 1,
#    'descricao': 'Bolsa Família',
#    'descricaoDetalhada': 'Bolsa Família'},
#   'valor': 99287.0,
#   'quantidadeBeneficiados': 733},
#  ...]

# %%
#  Making every json to a list member so I can append later in a dataframe
lst_final = [[item] for item in lst_recover]
lst_final
# Out:
# [[{'id': 75202990,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '1200013',
#     'nomeIBGE': 'ACRELÂNDIA',
#     'nomeIBGEsemAcento': 'ACRELANDIA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 307671.0,
#    'quantidadeBeneficiados': 1563}],
#  [{'id': 69202460,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '1200054',
#     'nomeIBGE': 'ASSIS BRASIL',
#     'nomeIBGEsemAcento': 'ASSIS BRASIL',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 443147.0,
#    'quantidadeBeneficiados': 1336}],
#  [{'id': 71003156,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '1200104',
#     'nomeIBGE': 'BRASILÉIA',
#     'nomeIBGEsemAcento': 'BRASILEIA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 615761.0,
#    'quantidadeBeneficiados': 3030}],
#  [{'id': 75803233,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '1200138',
#     'nomeIBGE': 'BUJARI',
#     'nomeIBGEsemAcento': 'BUJARI',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 305647.0,
#    'quantidadeBeneficiados': 1326}],
#  [{'id': 67505039,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '1200179',
#     'nomeIBGE': 'CAPIXABA',
#     'nomeIBGEsemAcento': 'CAPIXABA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 367782.0,
#    'quantidadeBeneficiados': 1444}],
#  [{'id': 69302315,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '1200203',
#     'nomeIBGE': 'CRUZEIRO DO SUL',
#     'nomeIBGEsemAcento': 'CRUZEIRO DO SUL',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 3357667.0,
#    'quantidadeBeneficiados': 10131}],
#  [{'id': 67602234,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '1200252',
#     'nomeIBGE': 'EPITACIOLÂNDIA',
#     'nomeIBGEsemAcento': 'EPITACIOLANDIA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 355090.0,
#    'quantidadeBeneficiados': 1659}],
#  [{'id': 74205461,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '1200302',
#     'nomeIBGE': 'FEIJÓ',
#     'nomeIBGEsemAcento': 'FEIJO',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 1422577.0,
#    'quantidadeBeneficiados': 4574}],
#  [{'id': 76303912,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '1200328',
#     'nomeIBGE': 'JORDÃO',
#     'nomeIBGEsemAcento': 'JORDAO',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 495942.0,
#    'quantidadeBeneficiados': 1258}],
#  [{'id': 65602695,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '1200336',
#     'nomeIBGE': 'MÂNCIO LIMA',
#     'nomeIBGEsemAcento': 'MANCIO LIMA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 1080155.0,
#    'quantidadeBeneficiados': 3074}],
#  [{'id': 62904887,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '1200344',
#     'nomeIBGE': 'MANOEL URBANO',
#     'nomeIBGEsemAcento': 'MANOEL URBANO',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 581350.0,
#    'quantidadeBeneficiados': 1684}],
#  [{'id': 66304642,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '1200351',
#     'nomeIBGE': 'MARECHAL THAUMATURGO',
#     'nomeIBGEsemAcento': 'MARECHAL THAUMATURGO',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 852171.0,
#    'quantidadeBeneficiados': 2658}],
#  [{'id': 66102422,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '1200385',
#     'nomeIBGE': 'PLÁCIDO DE CASTRO',
#     'nomeIBGEsemAcento': 'PLACIDO DE CASTRO',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 266134.0,
#    'quantidadeBeneficiados': 1449}],
#  [{'id': 67104567,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '1200807',
#     'nomeIBGE': 'PORTO ACRE',
#     'nomeIBGEsemAcento': 'PORTO ACRE',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 581937.0,
#    'quantidadeBeneficiados': 2554}],
#  [{'id': 74903626,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '1200393',
#     'nomeIBGE': 'PORTO WALTER',
#     'nomeIBGEsemAcento': 'PORTO WALTER',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 492542.0,
#    'quantidadeBeneficiados': 1473}],
#  [{'id': 65802364,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '1200401',
#     'nomeIBGE': 'RIO BRANCO',
#     'nomeIBGEsemAcento': 'RIO BRANCO',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 5123393.0,
#    'quantidadeBeneficiados': 20802}],
#  [{'id': 71002873,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '1200427',
#     'nomeIBGE': 'RODRIGUES ALVES',
#     'nomeIBGEsemAcento': 'RODRIGUES ALVES',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 736385.0,
#    'quantidadeBeneficiados': 2360}],
#  [{'id': 66603584,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '1200435',
#     'nomeIBGE': 'SANTA ROSA DO PURUS',
#     'nomeIBGEsemAcento': 'SANTA ROSA DO PURUS',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 423152.0,
#    'quantidadeBeneficiados': 1031}],
#  [{'id': 71302808,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '1200500',
#     'nomeIBGE': 'SENA MADUREIRA',
#     'nomeIBGEsemAcento': 'SENA MADUREIRA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 1977950.0,
#    'quantidadeBeneficiados': 6624}],
#  [{'id': 64304905,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '1200450',
#     'nomeIBGE': 'SENADOR GUIOMARD',
#     'nomeIBGEsemAcento': 'SENADOR GUIOMARD',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 1048032.0,
#    'quantidadeBeneficiados': 3849}],
#  [{'id': 73303704,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '1200609',
#     'nomeIBGE': 'TARAUACÁ',
#     'nomeIBGEsemAcento': 'TARAUACA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 2548146.0,
#    'quantidadeBeneficiados': 6956}],
#  [{'id': 62904919,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '1200708',
#     'nomeIBGE': 'XAPURI',
#     'nomeIBGEsemAcento': 'XAPURI',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AC', 'nome': 'ACRE'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 396041.0,
#    'quantidadeBeneficiados': 1919}],
#  [{'id': 68602487,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2700102',
#     'nomeIBGE': 'ÁGUA BRANCA',
#     'nomeIBGEsemAcento': 'AGUA BRANCA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 851437.0,
#    'quantidadeBeneficiados': 2767}],
#  [{'id': 67302958,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2700201',
#     'nomeIBGE': 'ANADIA',
#     'nomeIBGEsemAcento': 'ANADIA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 458752.0,
#    'quantidadeBeneficiados': 2534}],
#  [{'id': 66302386,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2700300',
#     'nomeIBGE': 'ARAPIRACA',
#     'nomeIBGEsemAcento': 'ARAPIRACA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 3386638.0,
#    'quantidadeBeneficiados': 17762}],
#  [{'id': 63204514,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2700409',
#     'nomeIBGE': 'ATALAIA',
#     'nomeIBGEsemAcento': 'ATALAIA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 1375879.0,
#    'quantidadeBeneficiados': 7197}],
#  [{'id': 68102881,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2700508',
#     'nomeIBGE': 'BARRA DE SANTO ANTÔNIO',
#     'nomeIBGEsemAcento': 'BARRA DE SANTO ANTONIO',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 705144.0,
#    'quantidadeBeneficiados': 3741}],
#  [{'id': 76603429,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2700607',
#     'nomeIBGE': 'BARRA DE SÃO MIGUEL',
#     'nomeIBGEsemAcento': 'BARRA DE SAO MIGUEL',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 247289.0,
#    'quantidadeBeneficiados': 1174}],
#  [{'id': 66804181,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2700706',
#     'nomeIBGE': 'BATALHA',
#     'nomeIBGEsemAcento': 'BATALHA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 732284.0,
#    'quantidadeBeneficiados': 3154}],
#  [{'id': 68605061,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2700805',
#     'nomeIBGE': 'BELÉM',
#     'nomeIBGEsemAcento': 'BELEM',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 181881.0,
#    'quantidadeBeneficiados': 839}],
#  [{'id': 69402244,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2700904',
#     'nomeIBGE': 'BELO MONTE',
#     'nomeIBGEsemAcento': 'BELO MONTE',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 308265.0,
#    'quantidadeBeneficiados': 1259}],
#  [{'id': 64903073,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2701001',
#     'nomeIBGE': 'BOCA DA MATA',
#     'nomeIBGEsemAcento': 'BOCA DA MATA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 746041.0,
#    'quantidadeBeneficiados': 3485}],
#  [{'id': 65703388,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2701100',
#     'nomeIBGE': 'BRANQUINHA',
#     'nomeIBGEsemAcento': 'BRANQUINHA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 317805.0,
#    'quantidadeBeneficiados': 1857}],
#  [{'id': 65403691,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2701209',
#     'nomeIBGE': 'CACIMBINHAS',
#     'nomeIBGEsemAcento': 'CACIMBINHAS',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 441611.0,
#    'quantidadeBeneficiados': 1946}],
#  [{'id': 71803264,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2701308',
#     'nomeIBGE': 'CAJUEIRO',
#     'nomeIBGEsemAcento': 'CAJUEIRO',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 590116.0,
#    'quantidadeBeneficiados': 3273}],
#  [{'id': 72202885,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2701357',
#     'nomeIBGE': 'CAMPESTRE',
#     'nomeIBGEsemAcento': 'CAMPESTRE',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 271222.0,
#    'quantidadeBeneficiados': 1373}],
#  [{'id': 69604398,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2701407',
#     'nomeIBGE': 'CAMPO ALEGRE',
#     'nomeIBGEsemAcento': 'CAMPO ALEGRE',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 891954.0,
#    'quantidadeBeneficiados': 5543}],
#  [{'id': 68902813,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2701506',
#     'nomeIBGE': 'CAMPO GRANDE',
#     'nomeIBGEsemAcento': 'CAMPO GRANDE',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 630795.0,
#    'quantidadeBeneficiados': 2215}],
#  [{'id': 70804777,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2701605',
#     'nomeIBGE': 'CANAPI',
#     'nomeIBGEsemAcento': 'CANAPI',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 1143155.0,
#    'quantidadeBeneficiados': 4114}],
#  [{'id': 72604916,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2701704',
#     'nomeIBGE': 'CAPELA',
#     'nomeIBGEsemAcento': 'CAPELA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 426397.0,
#    'quantidadeBeneficiados': 2074}],
#  [{'id': 76003899,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2701803',
#     'nomeIBGE': 'CARNEIROS',
#     'nomeIBGEsemAcento': 'CARNEIROS',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 491516.0,
#    'quantidadeBeneficiados': 1665}],
#  [{'id': 73904508,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2701902',
#     'nomeIBGE': 'CHÃ PRETA',
#     'nomeIBGEsemAcento': 'CHA PRETA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 335554.0,
#    'quantidadeBeneficiados': 1171}],
#  [{'id': 63004620,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2702009',
#     'nomeIBGE': 'COITÉ DO NÓIA',
#     'nomeIBGEsemAcento': 'COITE DO NOIA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 310497.0,
#    'quantidadeBeneficiados': 1435}],
#  [{'id': 67105139,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2702108',
#     'nomeIBGE': 'COLÔNIA LEOPOLDINA',
#     'nomeIBGEsemAcento': 'COLONIA LEOPOLDINA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 817811.0,
#    'quantidadeBeneficiados': 3983}],
#  [{'id': 75004539,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2702207',
#     'nomeIBGE': 'COQUEIRO SECO',
#     'nomeIBGEsemAcento': 'COQUEIRO SECO',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 114179.0,
#    'quantidadeBeneficiados': 664}],
#  [{'id': 75602355,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2702306',
#     'nomeIBGE': 'CORURIPE',
#     'nomeIBGEsemAcento': 'CORURIPE',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 866185.0,
#    'quantidadeBeneficiados': 4883}],
#  [{'id': 76504682,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2702355',
#     'nomeIBGE': 'CRAÍBAS',
#     'nomeIBGEsemAcento': 'CRAIBAS',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 968656.0,
#    'quantidadeBeneficiados': 3603}],
#  [{'id': 64602708,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2702405',
#     'nomeIBGE': 'DELMIRO GOUVEIA',
#     'nomeIBGEsemAcento': 'DELMIRO GOUVEIA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 1188387.0,
#    'quantidadeBeneficiados': 5896}],
#  [{'id': 66004945,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2702504',
#     'nomeIBGE': 'DOIS RIACHOS',
#     'nomeIBGEsemAcento': 'DOIS RIACHOS',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 276525.0,
#    'quantidadeBeneficiados': 1763}],
#  [{'id': 66904724,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2702553',
#     'nomeIBGE': 'ESTRELA DE ALAGOAS',
#     'nomeIBGEsemAcento': 'ESTRELA DE ALAGOAS',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 576903.0,
#    'quantidadeBeneficiados': 2386}],
#  [{'id': 68303597,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2702603',
#     'nomeIBGE': 'FEIRA GRANDE',
#     'nomeIBGEsemAcento': 'FEIRA GRANDE',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 850380.0,
#    'quantidadeBeneficiados': 4035}],
#  [{'id': 70902589,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2702702',
#     'nomeIBGE': 'FELIZ DESERTO',
#     'nomeIBGEsemAcento': 'FELIZ DESERTO',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 99824.0,
#    'quantidadeBeneficiados': 624}],
#  [{'id': 65303877,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2702801',
#     'nomeIBGE': 'FLEXEIRAS',
#     'nomeIBGEsemAcento': 'FLEXEIRAS',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 398250.0,
#    'quantidadeBeneficiados': 2029}],
#  [{'id': 67504277,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2702900',
#     'nomeIBGE': 'GIRAU DO PONCIANO',
#     'nomeIBGEsemAcento': 'GIRAU DO PONCIANO',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 1501454.0,
#    'quantidadeBeneficiados': 5397}],
#  [{'id': 63204648,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2703007',
#     'nomeIBGE': 'IBATEGUARA',
#     'nomeIBGEsemAcento': 'IBATEGUARA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 472593.0,
#    'quantidadeBeneficiados': 2242}],
#  [{'id': 69502720,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2703106',
#     'nomeIBGE': 'IGACI',
#     'nomeIBGEsemAcento': 'IGACI',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 1206315.0,
#    'quantidadeBeneficiados': 4589}],
#  [{'id': 71702291,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2703205',
#     'nomeIBGE': 'IGREJA NOVA',
#     'nomeIBGEsemAcento': 'IGREJA NOVA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 540666.0,
#    'quantidadeBeneficiados': 3214}],
#  [{'id': 62403058,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2703304',
#     'nomeIBGE': 'INHAPI',
#     'nomeIBGEsemAcento': 'INHAPI',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 616959.0,
#    'quantidadeBeneficiados': 2577}],
#  [{'id': 64605080,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2703403',
#     'nomeIBGE': 'JACARÉ DOS HOMENS',
#     'nomeIBGEsemAcento': 'JACARE DOS HOMENS',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 207384.0,
#    'quantidadeBeneficiados': 1085}],
#  [{'id': 76502462,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2703502',
#     'nomeIBGE': 'JACUÍPE',
#     'nomeIBGEsemAcento': 'JACUIPE',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 165784.0,
#    'quantidadeBeneficiados': 1025}],
#  [{'id': 73905017,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2703601',
#     'nomeIBGE': 'JAPARATINGA',
#     'nomeIBGEsemAcento': 'JAPARATINGA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 363361.0,
#    'quantidadeBeneficiados': 1775}],
#  [{'id': 62602832,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2703700',
#     'nomeIBGE': 'JARAMATAIA',
#     'nomeIBGEsemAcento': 'JARAMATAIA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 226405.0,
#    'quantidadeBeneficiados': 936}],
#  [{'id': 65904611,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2703759',
#     'nomeIBGE': 'JEQUIÁ DA PRAIA',
#     'nomeIBGEsemAcento': 'JEQUIA DA PRAIA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 494463.0,
#    'quantidadeBeneficiados': 2092}],
#  [{'id': 64302723,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2703809',
#     'nomeIBGE': 'JOAQUIM GOMES',
#     'nomeIBGEsemAcento': 'JOAQUIM GOMES',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 561955.0,
#    'quantidadeBeneficiados': 3169}],
#  [{'id': 72703209,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2703908',
#     'nomeIBGE': 'JUNDIÁ',
#     'nomeIBGEsemAcento': 'JUNDIA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 188324.0,
#    'quantidadeBeneficiados': 719}],
#  [{'id': 65603301,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2704005',
#     'nomeIBGE': 'JUNQUEIRO',
#     'nomeIBGEsemAcento': 'JUNQUEIRO',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 630584.0,
#    'quantidadeBeneficiados': 3629}],
#  [{'id': 73103443,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2704104',
#     'nomeIBGE': 'LAGOA DA CANOA',
#     'nomeIBGEsemAcento': 'LAGOA DA CANOA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 708681.0,
#    'quantidadeBeneficiados': 2928}],
#  [{'id': 62803733,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2704203',
#     'nomeIBGE': 'LIMOEIRO DE ANADIA',
#     'nomeIBGEsemAcento': 'LIMOEIRO DE ANADIA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 947633.0,
#    'quantidadeBeneficiados': 3851}],
#  [{'id': 66403597,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2704302',
#     'nomeIBGE': 'MACEIÓ',
#     'nomeIBGEsemAcento': 'MACEIO',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 8805285.0,
#    'quantidadeBeneficiados': 50585}],
#  [{'id': 66103686,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2704401',
#     'nomeIBGE': 'MAJOR ISIDORO',
#     'nomeIBGEsemAcento': 'MAJOR ISIDORO',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 704572.0,
#    'quantidadeBeneficiados': 3145}],
#  [{'id': 69704250,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2704906',
#     'nomeIBGE': 'MAR VERMELHO',
#     'nomeIBGEsemAcento': 'MAR VERMELHO',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 139647.0,
#    'quantidadeBeneficiados': 617}],
#  [{'id': 76704515,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2704500',
#     'nomeIBGE': 'MARAGOGI',
#     'nomeIBGEsemAcento': 'MARAGOGI',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 864225.0,
#    'quantidadeBeneficiados': 4656}],
#  [{'id': 67805017,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2704609',
#     'nomeIBGE': 'MARAVILHA',
#     'nomeIBGEsemAcento': 'MARAVILHA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 496400.0,
#    'quantidadeBeneficiados': 2624}],
#  [{'id': 70402451,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2704708',
#     'nomeIBGE': 'MARECHAL DEODORO',
#     'nomeIBGEsemAcento': 'MARECHAL DEODORO',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 1406713.0,
#    'quantidadeBeneficiados': 6604}],
#  [{'id': 63404311,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2704807',
#     'nomeIBGE': 'MARIBONDO',
#     'nomeIBGEsemAcento': 'MARIBONDO',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 332776.0,
#    'quantidadeBeneficiados': 1815}],
#  [{'id': 71304838,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2705002',
#     'nomeIBGE': 'MATA GRANDE',
#     'nomeIBGEsemAcento': 'MATA GRANDE',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 702559.0,
#    'quantidadeBeneficiados': 3343}],
#  [{'id': 66104417,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2705101',
#     'nomeIBGE': 'MATRIZ DE CAMARAGIBE',
#     'nomeIBGEsemAcento': 'MATRIZ DE CAMARAGIBE',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 590298.0,
#    'quantidadeBeneficiados': 3259}],
#  [{'id': 71705212,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2705200',
#     'nomeIBGE': 'MESSIAS',
#     'nomeIBGEsemAcento': 'MESSIAS',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 277950.0,
#    'quantidadeBeneficiados': 1556}],
#  [{'id': 64902176,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2705309',
#     'nomeIBGE': 'MINADOR DO NEGRÃO',
#     'nomeIBGEsemAcento': 'MINADOR DO NEGRAO',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 182751.0,
#    'quantidadeBeneficiados': 692}],
#  [{'id': 69703380,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2705408',
#     'nomeIBGE': 'MONTEIRÓPOLIS',
#     'nomeIBGEsemAcento': 'MONTEIROPOLIS',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 352295.0,
#    'quantidadeBeneficiados': 1509}],
#  [{'id': 68104003,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2705507',
#     'nomeIBGE': 'MURICI',
#     'nomeIBGEsemAcento': 'MURICI',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 823774.0,
#    'quantidadeBeneficiados': 3842}],
#  [{'id': 70403004,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2705606',
#     'nomeIBGE': 'NOVO LINO',
#     'nomeIBGEsemAcento': 'NOVO LINO',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 380079.0,
#    'quantidadeBeneficiados': 1839}],
#  [{'id': 70104451,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2705903',
#     'nomeIBGE': "OLHO D'ÁGUA GRANDE",
#     'nomeIBGEsemAcento': "OLHO D'AGUA GRANDE",
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 370155.0,
#    'quantidadeBeneficiados': 1299}],
#  [{'id': 65002659,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2705705',
#     'nomeIBGE': "OLHO D'ÁGUA DAS FLORES",
#     'nomeIBGEsemAcento': "OLHO D'AGUA DAS FLORES",
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 418964.0,
#    'quantidadeBeneficiados': 2611}],
#  [{'id': 67702550,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2705804',
#     'nomeIBGE': "OLHO D'ÁGUA DO CASADO",
#     'nomeIBGEsemAcento': "OLHO D'AGUA DO CASADO",
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 400950.0,
#    'quantidadeBeneficiados': 1646}],
#  [{'id': 67602378,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2706000',
#     'nomeIBGE': 'OLIVENÇA',
#     'nomeIBGEsemAcento': 'OLIVENCA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 569683.0,
#    'quantidadeBeneficiados': 2012}],
#  [{'id': 68703275,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2706109',
#     'nomeIBGE': 'OURO BRANCO',
#     'nomeIBGEsemAcento': 'OURO BRANCO',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 564860.0,
#    'quantidadeBeneficiados': 2479}],
#  [{'id': 71603238,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2706208',
#     'nomeIBGE': 'PALESTINA',
#     'nomeIBGEsemAcento': 'PALESTINA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 161013.0,
#    'quantidadeBeneficiados': 841}],
#  [{'id': 75403795,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2706307',
#     'nomeIBGE': 'PALMEIRA DOS ÍNDIOS',
#     'nomeIBGEsemAcento': 'PALMEIRA DOS INDIOS',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 1917599.0,
#    'quantidadeBeneficiados': 10220}],
#  [{'id': 74703848,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2706406',
#     'nomeIBGE': 'PÃO DE AÇÚCAR',
#     'nomeIBGEsemAcento': 'PAO DE ACUCAR',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 575350.0,
#    'quantidadeBeneficiados': 3444}],
#  [{'id': 68204004,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2706422',
#     'nomeIBGE': 'PARICONHA',
#     'nomeIBGEsemAcento': 'PARICONHA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 430998.0,
#    'quantidadeBeneficiados': 1678}],
#  [{'id': 64304750,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2706448',
#     'nomeIBGE': 'PARIPUEIRA',
#     'nomeIBGEsemAcento': 'PARIPUEIRA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 360005.0,
#    'quantidadeBeneficiados': 2070}],
#  [{'id': 67604327,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2706505',
#     'nomeIBGE': 'PASSO DE CAMARAGIBE',
#     'nomeIBGEsemAcento': 'PASSO DE CAMARAGIBE',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 365737.0,
#    'quantidadeBeneficiados': 1927}],
#  [{'id': 64303794,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2706604',
#     'nomeIBGE': 'PAULO JACINTO',
#     'nomeIBGEsemAcento': 'PAULO JACINTO',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 236147.0,
#    'quantidadeBeneficiados': 1234}],
#  [{'id': 70604234,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2706703',
#     'nomeIBGE': 'PENEDO',
#     'nomeIBGEsemAcento': 'PENEDO',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 1794968.0,
#    'quantidadeBeneficiados': 9340}],
#  [{'id': 67804743,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2706802',
#     'nomeIBGE': 'PIAÇABUÇU',
#     'nomeIBGEsemAcento': 'PIACABUCU',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 838147.0,
#    'quantidadeBeneficiados': 3954}],
#  [{'id': 76302204,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2706901',
#     'nomeIBGE': 'PILAR',
#     'nomeIBGEsemAcento': 'PILAR',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 919130.0,
#    'quantidadeBeneficiados': 5083}],
#  [{'id': 67502507,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2707008',
#     'nomeIBGE': 'PINDOBA',
#     'nomeIBGEsemAcento': 'PINDOBA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 71821.0,
#    'quantidadeBeneficiados': 299}],
#  [{'id': 63404756,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2707107',
#     'nomeIBGE': 'PIRANHAS',
#     'nomeIBGEsemAcento': 'PIRANHAS',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 882336.0,
#    'quantidadeBeneficiados': 3666}],
#  [{'id': 69603314,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2707206',
#     'nomeIBGE': 'POÇO DAS TRINCHEIRAS',
#     'nomeIBGEsemAcento': 'POCO DAS TRINCHEIRAS',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 666304.0,
#    'quantidadeBeneficiados': 2383}],
#  [{'id': 63902457,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2707305',
#     'nomeIBGE': 'PORTO CALVO',
#     'nomeIBGEsemAcento': 'PORTO CALVO',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 872899.0,
#    'quantidadeBeneficiados': 5214}],
#  [{'id': 72202867,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2707503',
#     'nomeIBGE': 'PORTO REAL DO COLÉGIO',
#     'nomeIBGEsemAcento': 'PORTO REAL DO COLEGIO',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 903046.0,
#    'quantidadeBeneficiados': 3811}],
#  [{'id': 69005141,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2707404',
#     'nomeIBGE': 'PORTO DE PEDRAS',
#     'nomeIBGEsemAcento': 'PORTO DE PEDRAS',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 287342.0,
#    'quantidadeBeneficiados': 1611}],
#  [{'id': 63903429,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2707602',
#     'nomeIBGE': 'QUEBRANGULO',
#     'nomeIBGEsemAcento': 'QUEBRANGULO',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 604128.0,
#    'quantidadeBeneficiados': 2221}],
#  [{'id': 67202951,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2707701',
#     'nomeIBGE': 'RIO LARGO',
#     'nomeIBGEsemAcento': 'RIO LARGO',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 1679483.0,
#    'quantidadeBeneficiados': 9766}],
#  [{'id': 63504092,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2707800',
#     'nomeIBGE': 'ROTEIRO',
#     'nomeIBGEsemAcento': 'ROTEIRO',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 240809.0,
#    'quantidadeBeneficiados': 1148}],
#  [{'id': 70603024,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2707909',
#     'nomeIBGE': 'SANTA LUZIA DO NORTE',
#     'nomeIBGEsemAcento': 'SANTA LUZIA DO NORTE',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 157329.0,
#    'quantidadeBeneficiados': 805}],
#  [{'id': 70504159,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2708006',
#     'nomeIBGE': 'SANTANA DO IPANEMA',
#     'nomeIBGEsemAcento': 'SANTANA DO IPANEMA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 1762686.0,
#    'quantidadeBeneficiados': 7543}],
#  [{'id': 69203597,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2708105',
#     'nomeIBGE': 'SANTANA DO MUNDAÚ',
#     'nomeIBGEsemAcento': 'SANTANA DO MUNDAU',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 294946.0,
#    'quantidadeBeneficiados': 1698}],
#  [{'id': 75803612,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2708204',
#     'nomeIBGE': 'SÃO BRÁS',
#     'nomeIBGEsemAcento': 'SAO BRAS',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 222660.0,
#    'quantidadeBeneficiados': 1016}],
#  [{'id': 74804615,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2708303',
#     'nomeIBGE': 'SÃO JOSÉ DA LAJE',
#     'nomeIBGEsemAcento': 'SAO JOSE DA LAJE',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 587222.0,
#    'quantidadeBeneficiados': 3103}],
#  [{'id': 75404459,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2708402',
#     'nomeIBGE': 'SÃO JOSÉ DA TAPERA',
#     'nomeIBGEsemAcento': 'SAO JOSE DA TAPERA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 1556931.0,
#    'quantidadeBeneficiados': 5943}],
#  [{'id': 65904876,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2708501',
#     'nomeIBGE': 'SÃO LUÍS DO QUITUNDE',
#     'nomeIBGEsemAcento': 'SAO LUIS DO QUITUNDE',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 1017676.0,
#    'quantidadeBeneficiados': 6077}],
#  [{'id': 76305269,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2708600',
#     'nomeIBGE': 'SÃO MIGUEL DOS CAMPOS',
#     'nomeIBGEsemAcento': 'SAO MIGUEL DOS CAMPOS',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 1255646.0,
#    'quantidadeBeneficiados': 7271}],
#  [{'id': 62702446,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2708709',
#     'nomeIBGE': 'SÃO MIGUEL DOS MILAGRES',
#     'nomeIBGEsemAcento': 'SAO MIGUEL DOS MILAGRES',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 204655.0,
#    'quantidadeBeneficiados': 1190}],
#  [{'id': 74704457,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2708808',
#     'nomeIBGE': 'SÃO SEBASTIÃO',
#     'nomeIBGEsemAcento': 'SAO SEBASTIAO',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 1294001.0,
#    'quantidadeBeneficiados': 5518}],
#  [{'id': 62604166,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2708907',
#     'nomeIBGE': 'SATUBA',
#     'nomeIBGEsemAcento': 'SATUBA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 313093.0,
#    'quantidadeBeneficiados': 1475}],
#  [{'id': 75704054,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2708956',
#     'nomeIBGE': 'SENADOR RUI PALMEIRA',
#     'nomeIBGEsemAcento': 'SENADOR RUI PALMEIRA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 568669.0,
#    'quantidadeBeneficiados': 2198}],
#  [{'id': 63905117,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2709004',
#     'nomeIBGE': "TANQUE D'ARCA",
#     'nomeIBGEsemAcento': "TANQUE D'ARCA",
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 215628.0,
#    'quantidadeBeneficiados': 984}],
#  [{'id': 69702044,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2709103',
#     'nomeIBGE': 'TAQUARANA',
#     'nomeIBGEsemAcento': 'TAQUARANA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 485042.0,
#    'quantidadeBeneficiados': 2388}],
#  [{'id': 72704907,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2709152',
#     'nomeIBGE': 'TEOTÔNIO VILELA',
#     'nomeIBGEsemAcento': 'TEOTONIO VILELA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'AL', 'nome': 'ALAGOAS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 955041.0,
#    'quantidadeBeneficiados': 4837}],
#  [{'id': 67102442,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '2709202',
#     'nomeIBGE': 'TRAIPU',
# ...
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 34424.0,
#    'quantidadeBeneficiados': 237}],
#  [{'id': 69402400,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5206909',
#     'nomeIBGE': 'DAVINÓPOLIS',
#     'nomeIBGEsemAcento': 'DAVINOPOLIS',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 13045.0,
#    'quantidadeBeneficiados': 93}],
#  [{'id': 67602794,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5207105',
#     'nomeIBGE': 'DIORAMA',
#     'nomeIBGEsemAcento': 'DIORAMA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 22764.0,
#    'quantidadeBeneficiados': 152}],
#  [{'id': 63603891,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5208301',
#     'nomeIBGE': 'DIVINÓPOLIS DE GOIÁS',
#     'nomeIBGEsemAcento': 'DIVINOPOLIS DE GOIAS',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 168830.0,
#    'quantidadeBeneficiados': 887}],
#  [{'id': 75003318,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5207253',
#     'nomeIBGE': 'DOVERLÂNDIA',
#     'nomeIBGEsemAcento': 'DOVERLANDIA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 115722.0,
#    'quantidadeBeneficiados': 602}],
#  [{'id': 63703133,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5207352',
#     'nomeIBGE': 'EDEALINA',
#     'nomeIBGEsemAcento': 'EDEALINA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 32900.0,
#    'quantidadeBeneficiados': 189}],
#  [{'id': 67603627,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5207402',
#     'nomeIBGE': 'EDÉIA',
#     'nomeIBGEsemAcento': 'EDEIA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 148079.0,
#    'quantidadeBeneficiados': 825}],
#  [{'id': 68402680,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5207501',
#     'nomeIBGE': 'ESTRELA DO NORTE',
#     'nomeIBGEsemAcento': 'ESTRELA DO NORTE',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 37507.0,
#    'quantidadeBeneficiados': 215}],
#  [{'id': 62402425,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5207535',
#     'nomeIBGE': 'FAINA',
#     'nomeIBGEsemAcento': 'FAINA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 85915.0,
#    'quantidadeBeneficiados': 519}],
#  [{'id': 64703880,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5207600',
#     'nomeIBGE': 'FAZENDA NOVA',
#     'nomeIBGEsemAcento': 'FAZENDA NOVA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 131695.0,
#    'quantidadeBeneficiados': 629}],
#  [{'id': 70604987,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5207808',
#     'nomeIBGE': 'FIRMINÓPOLIS',
#     'nomeIBGEsemAcento': 'FIRMINOPOLIS',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 82517.0,
#    'quantidadeBeneficiados': 535}],
#  [{'id': 72902351,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5207907',
#     'nomeIBGE': 'FLORES DE GOIÁS',
#     'nomeIBGEsemAcento': 'FLORES DE GOIAS',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 220028.0,
#    'quantidadeBeneficiados': 1272}],
#  [{'id': 63002795,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5208004',
#     'nomeIBGE': 'FORMOSA',
#     'nomeIBGEsemAcento': 'FORMOSA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 1176248.0,
#    'quantidadeBeneficiados': 6475}],
#  [{'id': 74903911,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5208103',
#     'nomeIBGE': 'FORMOSO',
#     'nomeIBGEsemAcento': 'FORMOSO',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 84816.0,
#    'quantidadeBeneficiados': 538}],
#  [{'id': 72304359,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5208152',
#     'nomeIBGE': 'GAMELEIRA DE GOIÁS',
#     'nomeIBGEsemAcento': 'GAMELEIRA DE GOIAS',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 23542.0,
#    'quantidadeBeneficiados': 140}],
#  [{'id': 75703406,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5208400',
#     'nomeIBGE': 'GOIANÁPOLIS',
#     'nomeIBGEsemAcento': 'GOIANAPOLIS',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 132631.0,
#    'quantidadeBeneficiados': 978}],
#  [{'id': 64004368,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5208509',
#     'nomeIBGE': 'GOIANDIRA',
#     'nomeIBGEsemAcento': 'GOIANDIRA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 28515.0,
#    'quantidadeBeneficiados': 198}],
#  [{'id': 64304498,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5208608',
#     'nomeIBGE': 'GOIANÉSIA',
#     'nomeIBGEsemAcento': 'GOIANESIA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 329795.0,
#    'quantidadeBeneficiados': 1941}],
#  [{'id': 67904436,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5208707',
#     'nomeIBGE': 'GOIÂNIA',
#     'nomeIBGEsemAcento': 'GOIANIA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 3630371.0,
#    'quantidadeBeneficiados': 22017}],
#  [{'id': 65904892,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5208806',
#     'nomeIBGE': 'GOIANIRA',
#     'nomeIBGEsemAcento': 'GOIANIRA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 338068.0,
#    'quantidadeBeneficiados': 1904}],
#  [{'id': 62903742,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5208905',
#     'nomeIBGE': 'GOIÁS',
#     'nomeIBGEsemAcento': 'GOIAS',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 194250.0,
#    'quantidadeBeneficiados': 1156}],
#  [{'id': 72904424,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5209101',
#     'nomeIBGE': 'GOIATUBA',
#     'nomeIBGEsemAcento': 'GOIATUBA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 154211.0,
#    'quantidadeBeneficiados': 1011}],
#  [{'id': 71904910,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5209150',
#     'nomeIBGE': 'GOUVELÂNDIA',
#     'nomeIBGEsemAcento': 'GOUVELANDIA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 22847.0,
#    'quantidadeBeneficiados': 150}],
#  [{'id': 75402524,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5209200',
#     'nomeIBGE': 'GUAPÓ',
#     'nomeIBGEsemAcento': 'GUAPO',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 256908.0,
#    'quantidadeBeneficiados': 1534}],
#  [{'id': 76002897,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5209291',
#     'nomeIBGE': 'GUARAÍTA',
#     'nomeIBGEsemAcento': 'GUARAITA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 34339.0,
#    'quantidadeBeneficiados': 230}],
#  [{'id': 65503837,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5209408',
#     'nomeIBGE': 'GUARANI DE GOIÁS',
#     'nomeIBGEsemAcento': 'GUARANI DE GOIAS',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 118882.0,
#    'quantidadeBeneficiados': 511}],
#  [{'id': 76304609,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5209457',
#     'nomeIBGE': 'GUARINOS',
#     'nomeIBGEsemAcento': 'GUARINOS',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 33904.0,
#    'quantidadeBeneficiados': 258}],
#  [{'id': 64802781,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5209606',
#     'nomeIBGE': 'HEITORAÍ',
#     'nomeIBGEsemAcento': 'HEITORAI',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 64059.0,
#    'quantidadeBeneficiados': 441}],
#  [{'id': 63203151,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5209705',
#     'nomeIBGE': 'HIDROLÂNDIA',
#     'nomeIBGEsemAcento': 'HIDROLANDIA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 127856.0,
#    'quantidadeBeneficiados': 819}],
#  [{'id': 64904606,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5209804',
#     'nomeIBGE': 'HIDROLINA',
#     'nomeIBGEsemAcento': 'HIDROLINA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 36519.0,
#    'quantidadeBeneficiados': 253}],
#  [{'id': 75002299,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5209903',
#     'nomeIBGE': 'IACIARA',
#     'nomeIBGEsemAcento': 'IACIARA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 293134.0,
#    'quantidadeBeneficiados': 1573}],
#  [{'id': 74004766,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5209952',
#     'nomeIBGE': 'INDIARA',
#     'nomeIBGEsemAcento': 'INDIARA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 117454.0,
#    'quantidadeBeneficiados': 774}],
#  [{'id': 68402880,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5210000',
#     'nomeIBGE': 'INHUMAS',
#     'nomeIBGEsemAcento': 'INHUMAS',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 307067.0,
#    'quantidadeBeneficiados': 1876}],
#  [{'id': 69105048,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5210109',
#     'nomeIBGE': 'IPAMERI',
#     'nomeIBGEsemAcento': 'IPAMERI',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 274695.0,
#    'quantidadeBeneficiados': 1434}],
#  [{'id': 69704286,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5210158',
#     'nomeIBGE': 'IPIRANGA DE GOIÁS',
#     'nomeIBGEsemAcento': 'IPIRANGA DE GOIAS',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 41098.0,
#    'quantidadeBeneficiados': 285}],
#  [{'id': 65903756,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5210208',
#     'nomeIBGE': 'IPORÁ',
#     'nomeIBGEsemAcento': 'IPORA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 63240.0,
#    'quantidadeBeneficiados': 490}],
#  [{'id': 65602517,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5210307',
#     'nomeIBGE': 'ISRAELÂNDIA',
#     'nomeIBGEsemAcento': 'ISRAELANDIA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 20347.0,
#    'quantidadeBeneficiados': 126}],
#  [{'id': 66404121,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5210406',
#     'nomeIBGE': 'ITABERAÍ',
#     'nomeIBGEsemAcento': 'ITABERAI',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 399936.0,
#    'quantidadeBeneficiados': 2654}],
#  [{'id': 69103435,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5210562',
#     'nomeIBGE': 'ITAGUARI',
#     'nomeIBGEsemAcento': 'ITAGUARI',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 41951.0,
#    'quantidadeBeneficiados': 292}],
#  [{'id': 75005076,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5210604',
#     'nomeIBGE': 'ITAGUARU',
#     'nomeIBGEsemAcento': 'ITAGUARU',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 54297.0,
#    'quantidadeBeneficiados': 358}],
#  [{'id': 66203403,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5210802',
#     'nomeIBGE': 'ITAJÁ',
#     'nomeIBGEsemAcento': 'ITAJA',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 38541.0,
#    'quantidadeBeneficiados': 216}],
#  [{'id': 69403921,
#    'dataReferencia': '01/11/2019',
#    'municipio': {'codigoIBGE': '5210901',
#     'nomeIBGE': 'ITAPACI',
#     'nomeIBGEsemAcento': 'ITAPACI',
#     'pais': 'BRASIL',
#     'uf': {'sigla': 'GO', 'nome': 'GOIÁS'}},
#    'tipo': {'id': 1,
#     'descricao': 'Bolsa Família',
#     'descricaoDetalhada': 'Bolsa Família'},
#    'valor': 99287.0,
#    'quantidadeBeneficiados': 733}],
#  ...]

# %%
# Missing 5 munip
errors_list = []
for pos, item in enumerate(lst,0):
    if item == 'Error API':
        print(pos)
        errors_list.append(pos)
# Out:
# 989
# 1674
# 2819
# 3114
# 3144

# %%
munip[989]
# Out:
# '5209937'

# %%
# lst_recover 5 missing munip
len(lst_recover)
# Out:
# 5565

# %%
lst[989]
# Out:
# 'Error API'

# %%
# Retriving lost data. With a small number of lost data I can retrieve manually these informations
for pos, item in enumerate(lst, 0):
    if item == 'Error API':
        url_api = f'http://www.transparencia.gov.br/api-de-dados/bolsa-familia-por-municipio?mesAno=201911&codigoIbge={munip[pos]}&pagina=1'
        lst_final.append(requests.get(url_api).json())

# %%
# Now I have all munip
len(lst_final)
# Out:
# 5570

# %% [markdown]
# # Making the Dataframe

# %%
# Now with all my json files I can create my dataframe
data = pd.DataFrame(lst_final,columns=['data'])
data
# Out:
#                                                    data
# 0     {'id': 75202990, 'dataReferencia': '01/11/2019...
# 1     {'id': 69202460, 'dataReferencia': '01/11/2019...
# 2     {'id': 71003156, 'dataReferencia': '01/11/2019...
# 3     {'id': 75803233, 'dataReferencia': '01/11/2019...
# 4     {'id': 67505039, 'dataReferencia': '01/11/2019...
# ...                                                 ...
# 5565  {'id': 76204217, 'dataReferencia': '01/11/2019...
# 5566  {'id': 67105272, 'dataReferencia': '01/11/2019...
# 5567  {'id': 67802654, 'dataReferencia': '01/11/2019...
# 5568  {'id': 69502247, 'dataReferencia': '01/11/2019...
# 5569  {'id': 72405455, 'dataReferencia': '01/11/2019...
#
# [5570 rows x 1 columns]

# %%
# flattening the data
data = flatten(data, ['data'])

# %%
data.head()
# Out:
#     data_id data_dataReferencia  \
# 0  75202990          01/11/2019
# 1  69202460          01/11/2019
# 2  71003156          01/11/2019
# 3  75803233          01/11/2019
# 4  67505039          01/11/2019
#
#                                       data_municipio  \
# 0  {'codigoIBGE': '1200013', 'nomeIBGE': 'ACRELÂN...
# 1  {'codigoIBGE': '1200054', 'nomeIBGE': 'ASSIS B...
# 2  {'codigoIBGE': '1200104', 'nomeIBGE': 'BRASILÉ...
# 3  {'codigoIBGE': '1200138', 'nomeIBGE': 'BUJARI'...
# 4  {'codigoIBGE': '1200179', 'nomeIBGE': 'CAPIXAB...
#
#                                            data_tipo  data_valor  \
# 0  {'id': 1, 'descricao': 'Bolsa Família', 'descr...    307671.0
# 1  {'id': 1, 'descricao': 'Bolsa Família', 'descr...    443147.0
# 2  {'id': 1, 'descricao': 'Bolsa Família', 'descr...    615761.0
# 3  {'id': 1, 'descricao': 'Bolsa Família', 'descr...    305647.0
# 4  {'id': 1, 'descricao': 'Bolsa Família', 'descr...    367782.0
#
#    data_quantidadeBeneficiados
# 0                         1563
# 1                         1336
# 2                         3030
# 3                         1326
# 4                         1444

# %%
data = flatten(data, ["data_municipio", "data_tipo"])
data.head()
# Out:
#     data_id data_dataReferencia  data_valor  data_quantidadeBeneficiados  \
# 0  75202990          01/11/2019    307671.0                         1563
# 1  69202460          01/11/2019    443147.0                         1336
# 2  71003156          01/11/2019    615761.0                         3030
# 3  75803233          01/11/2019    305647.0                         1326
# 4  67505039          01/11/2019    367782.0                         1444
#
#   data_municipio_codigoIBGE data_municipio_nomeIBGE  \
# 0                   1200013              ACRELÂNDIA
# 1                   1200054            ASSIS BRASIL
# 2                   1200104               BRASILÉIA
# 3                   1200138                  BUJARI
# 4                   1200179                CAPIXABA
#
#   data_municipio_nomeIBGEsemAcento data_municipio_pais  \
# 0                       ACRELANDIA              BRASIL
# 1                     ASSIS BRASIL              BRASIL
# 2                        BRASILEIA              BRASIL
# 3                           BUJARI              BRASIL
# 4                         CAPIXABA              BRASIL
#
#                  data_municipio_uf  data_tipo_id data_tipo_descricao  \
# 0  {'sigla': 'AC', 'nome': 'ACRE'}             1       Bolsa Família
# 1  {'sigla': 'AC', 'nome': 'ACRE'}             1       Bolsa Família
# 2  {'sigla': 'AC', 'nome': 'ACRE'}             1       Bolsa Família
# 3  {'sigla': 'AC', 'nome': 'ACRE'}             1       Bolsa Família
# 4  {'sigla': 'AC', 'nome': 'ACRE'}             1       Bolsa Família
#
#   data_tipo_descricaoDetalhada
# 0                Bolsa Família
# 1                Bolsa Família
# 2                Bolsa Família
# 3                Bolsa Família
# 4                Bolsa Família

# %%
data = flatten(data,['data_municipio_uf'])
data.head()
# Out:
#     data_id data_dataReferencia  data_valor  data_quantidadeBeneficiados  \
# 0  75202990          01/11/2019    307671.0                         1563
# 1  69202460          01/11/2019    443147.0                         1336
# 2  71003156          01/11/2019    615761.0                         3030
# 3  75803233          01/11/2019    305647.0                         1326
# 4  67505039          01/11/2019    367782.0                         1444
#
#   data_municipio_codigoIBGE data_municipio_nomeIBGE  \
# 0                   1200013              ACRELÂNDIA
# 1                   1200054            ASSIS BRASIL
# 2                   1200104               BRASILÉIA
# 3                   1200138                  BUJARI
# 4                   1200179                CAPIXABA
#
#   data_municipio_nomeIBGEsemAcento data_municipio_pais  data_tipo_id  \
# 0                       ACRELANDIA              BRASIL             1
# 1                     ASSIS BRASIL              BRASIL             1
# 2                        BRASILEIA              BRASIL             1
# 3                           BUJARI              BRASIL             1
# 4                         CAPIXABA              BRASIL             1
#
#   data_tipo_descricao data_tipo_descricaoDetalhada data_municipio_uf_sigla  \
# 0       Bolsa Família                Bolsa Família                      AC
# 1       Bolsa Família                Bolsa Família                      AC
# 2       Bolsa Família                Bolsa Família                      AC
# 3       Bolsa Família                Bolsa Família                      AC
# 4       Bolsa Família                Bolsa Família                      AC
#
#   data_municipio_uf_nome
# 0                   ACRE
# 1                   ACRE
# 2                   ACRE
# 3                   ACRE
# 4                   ACRE

# %% [markdown]
# Final Format

# %%
df = data[['data_dataReferencia','data_municipio_nomeIBGE','data_municipio_uf_sigla','data_tipo_descricao','data_quantidadeBeneficiados','data_valor']].copy()
df.head()
# Out:
#   data_dataReferencia data_municipio_nomeIBGE data_municipio_uf_sigla  \
# 0          01/11/2019              ACRELÂNDIA                      AC
# 1          01/11/2019            ASSIS BRASIL                      AC
# 2          01/11/2019               BRASILÉIA                      AC
# 3          01/11/2019                  BUJARI                      AC
# 4          01/11/2019                CAPIXABA                      AC
#
#   data_tipo_descricao  data_quantidadeBeneficiados  data_valor
# 0       Bolsa Família                         1563    307671.0
# 1       Bolsa Família                         1336    443147.0
# 2       Bolsa Família                         3030    615761.0
# 3       Bolsa Família                         1326    305647.0
# 4       Bolsa Família                         1444    367782.0

# %%
df.shape
# Out:
# (5570, 6)

# %% [markdown]
# # Another way to create the final dataset

# %%
df = pd.DataFrame(lst_final[0])
df
# Out:
#          id dataReferencia                                          municipio  \
# 0  75202990     01/11/2019  {'codigoIBGE': '1200013', 'nomeIBGE': 'ACRELÂN...
#
#                                                 tipo     valor  \
# 0  {'id': 1, 'descricao': 'Bolsa Família', 'descr...  307671.0
#
#    quantidadeBeneficiados
# 0                    1563

# %%
# Using lst_final[1:] because the dataframe is already created from the lst_final[0]
# Then now I only going to append the data
for data in lst_final[1:]:
    df= df.append(data)

# %%
df.head()
# Out:
#          id dataReferencia                                          municipio  \
# 0  75202990     01/11/2019  {'codigoIBGE': '1200013', 'nomeIBGE': 'ACRELÂN...
# 0  69202460     01/11/2019  {'codigoIBGE': '1200054', 'nomeIBGE': 'ASSIS B...
# 0  71003156     01/11/2019  {'codigoIBGE': '1200104', 'nomeIBGE': 'BRASILÉ...
# 0  75803233     01/11/2019  {'codigoIBGE': '1200138', 'nomeIBGE': 'BUJARI'...
# 0  67505039     01/11/2019  {'codigoIBGE': '1200179', 'nomeIBGE': 'CAPIXAB...
#
#                                                 tipo     valor  \
# 0  {'id': 1, 'descricao': 'Bolsa Família', 'descr...  307671.0
# 0  {'id': 1, 'descricao': 'Bolsa Família', 'descr...  443147.0
# 0  {'id': 1, 'descricao': 'Bolsa Família', 'descr...  615761.0
# 0  {'id': 1, 'descricao': 'Bolsa Família', 'descr...  305647.0
# 0  {'id': 1, 'descricao': 'Bolsa Família', 'descr...  367782.0
#
#    quantidadeBeneficiados
# 0                    1563
# 0                    1336
# 0                    3030
# 0                    1326
# 0                    1444

# %%
# Now remaking the index
df.reset_index(inplace=True)
df.drop(columns='index',inplace=True)

# %%
df.head()
# Out:
#          id dataReferencia                                          municipio  \
# 0  75202990     01/11/2019  {'codigoIBGE': '1200013', 'nomeIBGE': 'ACRELÂN...
# 1  69202460     01/11/2019  {'codigoIBGE': '1200054', 'nomeIBGE': 'ASSIS B...
# 2  71003156     01/11/2019  {'codigoIBGE': '1200104', 'nomeIBGE': 'BRASILÉ...
# 3  75803233     01/11/2019  {'codigoIBGE': '1200138', 'nomeIBGE': 'BUJARI'...
# 4  67505039     01/11/2019  {'codigoIBGE': '1200179', 'nomeIBGE': 'CAPIXAB...
#
#                                                 tipo     valor  \
# 0  {'id': 1, 'descricao': 'Bolsa Família', 'descr...  307671.0
# 1  {'id': 1, 'descricao': 'Bolsa Família', 'descr...  443147.0
# 2  {'id': 1, 'descricao': 'Bolsa Família', 'descr...  615761.0
# 3  {'id': 1, 'descricao': 'Bolsa Família', 'descr...  305647.0
# 4  {'id': 1, 'descricao': 'Bolsa Família', 'descr...  367782.0
#
#    quantidadeBeneficiados
# 0                    1563
# 1                    1336
# 2                    3030
# 3                    1326
# 4                    1444

# %%
df = flatten(df, ["municipio", "tipo"])
df.head()
# Out:
#          id dataReferencia     valor  quantidadeBeneficiados  \
# 0  75202990     01/11/2019  307671.0                    1563
# 1  69202460     01/11/2019  443147.0                    1336
# 2  71003156     01/11/2019  615761.0                    3030
# 3  75803233     01/11/2019  305647.0                    1326
# 4  67505039     01/11/2019  367782.0                    1444
#
#   municipio_codigoIBGE municipio_nomeIBGE municipio_nomeIBGEsemAcento  \
# 0              1200013         ACRELÂNDIA                  ACRELANDIA
# 1              1200054       ASSIS BRASIL                ASSIS BRASIL
# 2              1200104          BRASILÉIA                   BRASILEIA
# 3              1200138             BUJARI                      BUJARI
# 4              1200179           CAPIXABA                    CAPIXABA
#
#   municipio_pais                     municipio_uf  tipo_id tipo_descricao  \
# 0         BRASIL  {'sigla': 'AC', 'nome': 'ACRE'}        1  Bolsa Família
# 1         BRASIL  {'sigla': 'AC', 'nome': 'ACRE'}        1  Bolsa Família
# 2         BRASIL  {'sigla': 'AC', 'nome': 'ACRE'}        1  Bolsa Família
# 3         BRASIL  {'sigla': 'AC', 'nome': 'ACRE'}        1  Bolsa Família
# 4         BRASIL  {'sigla': 'AC', 'nome': 'ACRE'}        1  Bolsa Família
#
#   tipo_descricaoDetalhada
# 0           Bolsa Família
# 1           Bolsa Família
# 2           Bolsa Família
# 3           Bolsa Família
# 4           Bolsa Família

# %%
df = flatten(df, ["municipio_uf"])
df.head()
# Out:
#          id dataReferencia     valor  quantidadeBeneficiados  \
# 0  75202990     01/11/2019  307671.0                    1563
# 1  69202460     01/11/2019  443147.0                    1336
# 2  71003156     01/11/2019  615761.0                    3030
# 3  75803233     01/11/2019  305647.0                    1326
# 4  67505039     01/11/2019  367782.0                    1444
#
#   municipio_codigoIBGE municipio_nomeIBGE municipio_nomeIBGEsemAcento  \
# 0              1200013         ACRELÂNDIA                  ACRELANDIA
# 1              1200054       ASSIS BRASIL                ASSIS BRASIL
# 2              1200104          BRASILÉIA                   BRASILEIA
# 3              1200138             BUJARI                      BUJARI
# 4              1200179           CAPIXABA                    CAPIXABA
#
#   municipio_pais  tipo_id tipo_descricao tipo_descricaoDetalhada  \
# 0         BRASIL        1  Bolsa Família           Bolsa Família
# 1         BRASIL        1  Bolsa Família           Bolsa Família
# 2         BRASIL        1  Bolsa Família           Bolsa Família
# 3         BRASIL        1  Bolsa Família           Bolsa Família
# 4         BRASIL        1  Bolsa Família           Bolsa Família
#
#   municipio_uf_sigla municipio_uf_nome
# 0                 AC              ACRE
# 1                 AC              ACRE
# 2                 AC              ACRE
# 3                 AC              ACRE
# 4                 AC              ACRE

# %%
df_final = df[['dataReferencia','municipio_nomeIBGE','municipio_uf_sigla','tipo_descricao','quantidadeBeneficiados','valor']].copy()
df_final.head()
# Out:
#   dataReferencia municipio_nomeIBGE municipio_uf_sigla tipo_descricao  \
# 0     01/11/2019         ACRELÂNDIA                 AC  Bolsa Família
# 1     01/11/2019       ASSIS BRASIL                 AC  Bolsa Família
# 2     01/11/2019          BRASILÉIA                 AC  Bolsa Família
# 3     01/11/2019             BUJARI                 AC  Bolsa Família
# 4     01/11/2019           CAPIXABA                 AC  Bolsa Família
#
#    quantidadeBeneficiados     valor
# 0                    1563  307671.0
# 1                    1336  443147.0
# 2                    3030  615761.0
# 3                    1326  305647.0
# 4                    1444  367782.0

# %%
# df.to_csv('final_format.csv')

# %%
df.groupby(['municipio_uf_sigla'])[['quantidadeBeneficiados', 'valor']].sum().reset_index()
# Out:
#    municipio_uf_sigla  quantidadeBeneficiados        valor
# 0                  AC                   82754   23778672.0
# 1                  AL                  373976   76039758.0
# 2                  AM                  366715   90121807.0
# 3                  AP                   70139   17140023.0
# 4                  BA                 1689947  332058293.0
# 5                  CE                  982378  194196981.0
# 6                  DF                   61517   12110463.0
# 7                  ES                  156301   29878861.0
# 8                  GO                  262302   44768677.0
# 9                  MA                  897598  201248934.0
# 10                 MG                  917457  179237536.0
# 11                 MS                  107640   21036205.0
# 12                 MT                  135579   24709549.0
# 13                 PA                  878005  187978171.0
# 14                 PB                  484583  102396912.0
# 15                 PE                 1081763  210126867.0
# 16                 PI                  422778   93059538.0
# 17                 PR                  316223   55975354.0
# 18                 RJ                  743241  153345593.0
# 19                 RN                  328599   64434084.0
# 20                 RO                   67946   11137371.0
# 21                 RR                   39069    9737335.0
# 22                 RS                  303888   57049710.0
# 23                 SC                   96522   18984261.0
# 24                 SE                  270900   48279674.0
# 25                 SP                 1263725  240167737.0
# 26                 TO                  106589   21212593.0

# %%
df[df['municipio_uf_sigla'] == 'SP'][['quantidadeBeneficiados']].sum()
# Out:
# quantidadeBeneficiados    1263725
# dtype: int64

# %%
# Same as above, but this time using the .pivot_table function
state = df.pivot_table(values=['quantidadeBeneficiados', 'valor'],
              index='municipio_uf_sigla',
              aggfunc='sum').reset_index()

# %%
state
# Out:
#    municipio_uf_sigla  quantidadeBeneficiados        valor
# 0                  AC                   82754   23778672.0
# 1                  AL                  373976   76039758.0
# 2                  AM                  366715   90121807.0
# 3                  AP                   70139   17140023.0
# 4                  BA                 1689947  332058293.0
# 5                  CE                  982378  194196981.0
# 6                  DF                   61517   12110463.0
# 7                  ES                  156301   29878861.0
# 8                  GO                  262302   44768677.0
# 9                  MA                  897598  201248934.0
# 10                 MG                  917457  179237536.0
# 11                 MS                  107640   21036205.0
# 12                 MT                  135579   24709549.0
# 13                 PA                  878005  187978171.0
# 14                 PB                  484583  102396912.0
# 15                 PE                 1081763  210126867.0
# 16                 PI                  422778   93059538.0
# 17                 PR                  316223   55975354.0
# 18                 RJ                  743241  153345593.0
# 19                 RN                  328599   64434084.0
# 20                 RO                   67946   11137371.0
# 21                 RR                   39069    9737335.0
# 22                 RS                  303888   57049710.0
# 23                 SC                   96522   18984261.0
# 24                 SE                  270900   48279674.0
# 25                 SP                 1263725  240167737.0
# 26                 TO                  106589   21212593.0

# %%
def regiao_brasil(lst):
    lst_norte = ['AC','AP','AM','PA','RO','RR','TO']
    lst_nordeste = ['AL','BA','CE','MA','PB','PI','PE','RN','SE']
    lst_centro = ['DF','GO','MT','MS']
    lst_sudeste = ['ES','MG','RJ','SP']
    lst_sul = ['PR','RS','SC']
#     for sigla in lst:
    if lst in lst_norte:
        return 'Norte'
    elif lst in lst_nordeste:
        return 'Nordeste'
    elif lst in lst_centro:
        return 'Centro-Oeste'
    elif lst in lst_sudeste:
        return 'Sudeste'
    elif lst in lst_sul:
        return 'Sul'

# %%
state['regiao'] = state['municipio_uf_sigla'].apply(regiao_brasil)

# %%
state.sort_values('regiao',inplace=True)

# %%
state.reset_index(drop='index',inplace=True)

# %%
state
# Out:
#    municipio_uf_sigla  quantidadeBeneficiados        valor        regiao
# 0                  DF                   61517   12110463.0  Centro-Oeste
# 1                  GO                  262302   44768677.0  Centro-Oeste
# 2                  MS                  107640   21036205.0  Centro-Oeste
# 3                  MT                  135579   24709549.0  Centro-Oeste
# 4                  AL                  373976   76039758.0      Nordeste
# 5                  SE                  270900   48279674.0      Nordeste
# 6                  BA                 1689947  332058293.0      Nordeste
# 7                  CE                  982378  194196981.0      Nordeste
# 8                  MA                  897598  201248934.0      Nordeste
# 9                  RN                  328599   64434084.0      Nordeste
# 10                 PI                  422778   93059538.0      Nordeste
# 11                 PB                  484583  102396912.0      Nordeste
# 12                 PE                 1081763  210126867.0      Nordeste
# 13                 AC                   82754   23778672.0         Norte
# 14                 RR                   39069    9737335.0         Norte
# 15                 RO                   67946   11137371.0         Norte
# 16                 PA                  878005  187978171.0         Norte
# 17                 AP                   70139   17140023.0         Norte
# 18                 AM                  366715   90121807.0         Norte
# 19                 TO                  106589   21212593.0         Norte
# 20                 RJ                  743241  153345593.0       Sudeste
# 21                 MG                  917457  179237536.0       Sudeste
# 22                 ES                  156301   29878861.0       Sudeste
# 23                 SP                 1263725  240167737.0       Sudeste
# 24                 PR                  316223   55975354.0           Sul
# 25                 RS                  303888   57049710.0           Sul
# 26                 SC                   96522   18984261.0           Sul

# %%
state.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 4 columns):
# municipio_uf_sigla        27 non-null object
# quantidadeBeneficiados    27 non-null int64
# valor                     27 non-null float64
# regiao                    27 non-null object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 992.0+ bytes

# %%
state['valor'] = state['valor'].astype('Int64')

# %%
state.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 4 columns):
# municipio_uf_sigla        27 non-null object
# quantidadeBeneficiados    27 non-null int64
# valor                     27 non-null Int64
# regiao                    27 non-null object
# dtypes: Int64(1), int64(1), object(2)
# memory usage: 1019.0+ bytes

# %%
state.groupby('regiao').sum().reset_index()
# Out:
#          regiao  quantidadeBeneficiados       valor
# 0  Centro-Oeste                  567038   102624894
# 1      Nordeste                 6532522  1321841041
# 2         Norte                 1611217   361105972
# 3       Sudeste                 3080724   602629727
# 4           Sul                  716633   132009325

# %%
region = state.pivot_table(values=['quantidadeBeneficiados', 'valor'],
                           index='regiao',
                           aggfunc='sum').reset_index()

# %%
region
# Out:
#          regiao  quantidadeBeneficiados       valor
# 0  Centro-Oeste                  567038   102624894
# 1      Nordeste                 6532522  1321841041
# 2         Norte                 1611217   361105972
# 3       Sudeste                 3080724   602629727
# 4           Sul                  716633   132009325

# %%
fig = plt.figure()

# Adiciona eixos à figura
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # esquerda, inferior, largura, altura (faixa de 0 a 1)

# Plota nos eixos especificados
axes.plot(x, y, 'b')
axes.set_xlabel('Define o Label X') # Perceba o uso de "set_" para começar métodos
axes.set_ylabel('Define o Label Y')
axes.set_title('Define o Título');

# %%
x = [1,2,3,4,5,6,7,8,9]
y = [1,4,9,16,25,36,49,64,81]
z = [2,4,6,8,10,12,14,16,18]

# %%
# create a subplot
plt.subplot(
    # nrows
    1,
    # ncols
    3,
    # index
    1)

# plot the x
plt.plot(x,y,
         # linewidth
         lw=3,
         # color = blue
         color="b", 
         # linestyle
         ls='--')

# create a second subplot
plt.subplot(1,3,2)

# plot the elements by
plt.plot(x,z,
         # linewidth
         lw=3, 
         # color
         color="r",
         # linestyle
         ls='-')

# create a second subplot
plt.subplot(1,3,3)

# plot the elements by
plt.plot(x,z,
         # linewidth
         lw=3, 
         # color
         color="g",
         # linestyle
         ls='-')

plt.subplot(1,3,1)

# %%
plt.style.use('classic')
sns.set_style('darkgrid')
plt.rcParams['figure.figsize'] = (12, 5)

df['municipio_uf_sigla'].hist(bins=27,color='gray')
fig.legend(labels=['municipio_uf_sigla'])

# %%
sns.set_style('darkgrid')
plt.rcParams['figure.figsize'] = (9, 5)

sns.barplot(region['regiao'].values,region['quantidadeBeneficiados'].values)

# %%
# Set style
sns.set(style="whitegrid", color_codes=True)
bar = sns.barplot(x="regiao", y="quantidadeBeneficiados",hue='regiao',data=region);
plt.show()

# %%
x = df.groupby('municipio_uf_nome').count()

# %%
x = x.index

# %%
x

# %%
y = df.groupby('municipio_uf_nome')['municipio_uf_nome'].count().values

# %%
y

# %%
plt.rcParams['figure.figsize'] = (22, 15)
sns.set(style="whitegrid", color_codes=True)
bar = sns.barplot(x=x, y=y,data=region);
plt.show()
